# %%
import webbrowser
import os
import requests
import bs4
from urllib.request import urlopen # 사이트에 요청 신호를 보내는 함수
import pandas as pd

# %%
# --- 1. "Tistory 요청 및 응답 분석" (Tistory Request and Analysis) ----


# Tistory 홈페이지의 URL을 'url' 변수에 저장합니다.
url = 'https://www.tistory.com'

# "requests.get(url)" 함수를 사용하여 해당 URL로 HTTP GET 요청을 보냅니다.
# 서버로부터 받은 "Response 객체"를 'response' 변수에 저장합니다.
response = requests.get(url)

# Response 객체의 "status_code" 속성을 출력합니다.
# "status_code"는 요청의 성공/실패 여부를 나타내는 HTTP 응답 코드입니다.
# "200"이 출력되면 요청이 "성공적"이었음을 의미합니다.
print(response.status_code)

# Response 객체의 "text" 속성(응답으로 받은 HTML 소스 코드) 중 
# 인덱스 5036부터 6983까지의 문자열 조각을 잘라내어 출력합니다.
# 이 코드는 웹페이지의 "특정 부분"만 확인하고자 할 때 사용됩니다.
print(response.text[5036:6983])
# Out:
# 200
# "https://t1.kakaocdn.net/kakao_js_sdk/2.7.3/kakao.min.js" as="script" crossorigin="" integrity="sha384-kLbo2SvoNtOFiniJ1EQ9o2iDA8i3xp+O6Cns+L5cd4RsOJfl+43z5pvieT2ayq3C"/><title>티스토리</title><meta name="description" content="좀 아는 블로거들의 유용한 이야기, 티스토리. 블로그, 포트폴리오, 웹사이트까지 티스토리에서 나를 표현해 보세요."/><meta property="og:title" content="티스토리"/><meta property="og:description" content="좀 아는 블로거들의 유용한 이야기, 티스토리. 블로그, 포트폴리오, 웹사이트까지 티스토리에서 나를 표현해 보세요."/><meta property="og:image" content="https://t1.daumcdn.net/tistory_admin/static/images/openGraph/tistoryOpengraph.png"/><meta property="og:image:alt" content="좀 아는 블로거들의 유용한 이야기, 티스토리. 블로그, 포트폴리오, 웹사이트까지 티스토리에서 나를 표현해 보세요."/><meta name="twitter:card" content="summary_large_image"/><meta name="twitter:title" content="티스토리"/><meta name="twitter:description" content="좀 아는 블로거들의 유용한 이야기, 티스토리. 블로그, 포트폴리오, 웹사이트까지 티스토리에서 나를 표현해 보세요."/><meta name="twitter:image" content="https://t1.daumcdn.net/tistory_admin/static/images/openGraph/tistoryOpengraph.png"/><meta name="twitter:image:alt" content="좀 아는 블로거들의 유용한 이야기, 티스토리. 블로그, 포트폴리오, 웹사이트까지 티스토리에서 나를 표현해 보세요."/><link rel="shortcut icon" href="https://t1.daumcdn.net/tistory_admin/favicon/tistory_favicon_32x32.ico"/><link rel="icon" href="https://t1.daumcdn.net/tistory_admin/top_v2/bi-tistory-favicon.svg"/><link rel="apple-touch-icon" href="https://t1.daumcdn.net/tistory_admin/top_v2/tistory-apple-touch-favicon.png"/><script>(self.__next_s=self.__next_s||[]).push(["//t1.daumcdn.net/tiara/js/v1/tiara-1.2.0.min.js",{}])</script><script src="/_next/static/chunks/polyfills-42372ed130431b0a.js" noModule=""></script></head><body><div id="kakaoIndex"><a href="#kakaoBody">본문 바로가기</a><a href="#kakaoLnb">메뉴 바로가기</a></div><div id="kakaoWrap"><div class="kakao_head head_type1" id="kakaoHead" role="banner"><div class="inner_header tistory"><div class="group_head"><h1><a class="link_logo" id="kakaoServiceLogo" href="/"><span class="img_common_tistory tit_tistory

# %%
# --- 2. "Google 요청 및 응답 분석" (Google Request and Analysis) ---


# Google Korea로 HTTP GET 요청을 보내고, Response 객체를 'r' 변수에 저장합니다.
r = requests.get("https://www.google.co.kr")

# Response 객체 자체를 출력합니다. (예: "<Response [200]>")
print(r)

# Response 객체의 "text" 속성(HTML 소스 코드 전체)을 출력합니다.
# Google의 HTML은 대부분 JavaScript로 이루어져 있어 읽기 어려울 수 있습니다.
print(r.text)

# Response 객체의 HTML 소스 코드 문자열의 "총 길이"(문자 수)를 출력합니다.
print(len(r.text))

# HTML 소스 코드의 "앞에서 100자"까지만 잘라내어 출력합니다.
# 이는 응답이 제대로 왔는지 빠르게 확인하는 용도로 사용됩니다.
print(r.text[0:100])
# Out:
# <Response [200]>
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="undWibf7tMwnEHLfrZmdxg">(function(){var _g={kEI:'haIyaejaFenJkPIPtaez0AY',kEXPI:'0,4240045,48791,46127,344796,270476,5262119,12,85,7,94,37,5987543,30823995,25228681,152385,65164,30633,9139,4599,328,6225,1116,49460,12880,709,23261,37798,28339,49898,4661,18880,9728,3856,33385,4719,11805,9706,3590,2158,19843,5683,3605,27684,9367,21897,1,4371,6292,16179,2646,101,2,4,1,1164,4926,91,10621,2305,4035,996,9592,4914,792,590,4,1378,136,3355,197,570,5243,2,5999,16,237,1168,3024,5478,4384,2,876,2229,5089,19,3008,14,781,15045,6,6406,1797,1400,426,10512,1031,1034,1212,3091,845,2047,1,1,4,12,428,1128,3,9,2833,9,27,8,3055,132,880,1745,4,2009,2626,9736,822,4,2200,12,3,565,5,1113,389,4,193,105,2349,5,2708,1502,609,15,164,570,298,2415,1397,497,4944,662,613,7,2834,2,2338,95,74,4,5955,132,881,238,4,82,1826,18,728,2,1088,2,4285,4,956,1649,4,794,819,22,187,3,6,2,2,2,5353,257,477,746,5,438,4,792,1,2,1081,20,2,299,3,517,362,196,5,244,35,3,2140,3,2788,49,10,215,215,226,797,1008,223,11,1508,381,2,1636,16,4,555,1541,1034,812,484,5,97,187,201,662,804,438,5,259,5,197,926,248,1192,19,295,399,749,4,93,4,235,140,139,911,129,78,110,282,4,17,319,165,137,54,3,9,1995,5,272,183,120,6,147,5,1512,42,4,443,24,965,1251,148,797,141,398,4,93,300,3,2,2,2,580,199,3,2,2,2,341,164,193,273,246,5,353,806,150,1003,5,57,91,613,2,3,2,138,55,267,562,250,46,170,264,84,150,10,4,29,805,401,264,259,4,484,307,89,22,821,302,19,5,237,209,116,128,4,1724,3,291,533,2,26,16,324,1,813,6,778,343,411,611,296,58,766,209,453,4,110,263,250,54,123,1029,3,2,2,2,2956,230,157,1,230,875,87,315,1979,285,277,1,2,561,2836,1,2,20617315,397589,18488,5,2992,4,2960,3,2022,6469,2,1558,3,12411,2,765,1670,25,52,1143,3,739,6,1082,1387,2,4,2,1545,917,552,2,1244,4,283,113,318,87,275,282,3,87,16,635,516,6492011,2556919,1078151,209655,562,10844238,1,450961,4,540776,65424,1,112,8158,1,3,9',kBL:'tCIY',kOPI:89978449};(function(){var a;((a=window.google)==null?0:a.stvsc)?google.kEI=_g.kEI:window.google=_g;}).call(this);})();(function(){google.sn='webhp';google.kHL='ko';google.rdn=false;})();(function(){
# var g=this||self;function k(){return window.google&&window.google.kOPI||null};var l,m=[];function n(a){for(var b;a&&(!a.getAttribute||!(b=a.getAttribute("eid")));)a=a.parentNode;return b||l}function p(a){for(var b=null;a&&(!a.getAttribute||!(b=a.getAttribute("leid")));)a=a.parentNode;return b}function q(a){/^http:/i.test(a)&&window.location.protocol==="https:"&&(google.ml&&google.ml(Error("a"),!1,{src:a,glmm:1}),a="");return a}
# function r(a,b,d,c,h){var e="";b.search("&ei=")===-1&&(e="&ei="+n(c),b.search("&lei=")===-1&&(c=p(c))&&(e+="&lei="+c));var f=b.search("&cshid=")===-1&&a!=="slh";c="&zx="+Date.now().toString();g._cshid&&f&&(c+="&cshid="+g._cshid);(d=d())&&(c+="&opi="+d);return"/"+(h||"gen_204")+"?atyp=i&ct="+String(a)+"&cad="+(b+e+c)};l=google.kEI;google.getEI=n;google.getLEI=p;google.ml=function(){return null};google.log=function(a,b,d,c,h,e){e=e===void 0?k:e;d||(d=r(a,b,e,c,h));if(d=q(d)){a=new Image;var f=m.length;m[f]=a;a.onerror=a.onload=a.onabort=function(){delete m[f]};a.src=d}};google.logUrl=function(a,b){b=b===void 0?k:b;return r("",a,b)};}).call(this);(function(){google.y={};google.sy={};function e(a,b,c){if(a)var d=a.id;else{do d=Math.random();while(c[d])}c[d]=[a,b]}var f;(f=google).x||(f.x=function(a,b){e(a,b,google.y)});var g;(g=google).sx||(g.sx=function(a,b){e(a,b,google.sy)});google.lm=[];var h;(h=google).plm||(h.plm=function(a){google.lm.push.apply(google.lm,a)});google.lq=[];var k;(k=google).load||(k.load=function(a,b,c){google.lq.push([[a],b,c])});var l;(l=google).loadAll||(l.loadAll=function(a,b){google.lq.push([a,b])});google.bx=!1;var m;(m=google).lx||(m.lx=function(){});var n=[],p;(p=google).fce||(p.fce=function(a,b,c,d){n.push([a,b,c,d])});google.qce=n;google.adl=[];}).call(this);google.f={};(function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a=c==="1"||c==="q"&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if(a.tagName==="A"){a=a.getAttribute("data-nohref")==="1";break a}a=!1}a&&b.preventDefault()},!0);}).call(this);</script><style>#gbar,#guser{font-size:13px;padding-top:1px !important;}#gbar{height:22px}#guser{padding-bottom:7px !important;text-align:right}.gbh,.gbd{border-top:1px solid #c9d7f1;font-size:1px}.gbh{height:0;position:absolute;top:24px;width:100%}@media all{.gb1{height:22px;margin-right:.5em;vertical-align:top}#gbar{float:left}}a.gb1,a.gb4{text-decoration:underline !important}a.gb1,a.gb4{color:#00c !important}.gbi .gb4{color:#dd8e27 !important}.gbf .gb4{color:#900 !important}
# </style><style>body,td,a,p,.h{font-family:&#44404;&#47548;,&#46027;&#50880;,sans-serif}.ko{font-size:9pt}body{margin:0;overflow-y:scroll}#gog{padding:3px 8px 0}td{line-height:.8em}.gac_m td{line-height:17px}form{margin-bottom:20px}.h{color:#1967d2}em{font-weight:bold;font-style:normal}.lst{height:25px;width:496px}.gsfi,.lst{font:18px sans-serif}.gsfs{font:17px sans-serif}.ds{display:inline-box;display:inline-block;margin:3px 0 4px;margin-left:4px}input{font-family:inherit}body{background:#fff;color:#1f1f1f}a{color:#681da8;text-decoration:none}a:hover,a:active{text-decoration:underline}.fl a{color:#1967d2}a:visited{color:#681da8}.sblc{padding-top:5px}.sblc a{display:block;margin:2px 0;margin-left:13px;font-size:11px}.lsbb{background:#ecedee;border:solid 1px;border-color:#d2d2d2 #70757a #70757a #d2d2d2;height:30px}.lsbb{display:block}#WqQANb a{display:inline-block;margin:0 12px}.lsb{background:url(/images/nav_logo229.png) 0 -261px repeat-x;color:#1f1f1f;border:none;cursor:pointer;height:30px;margin:0;outline:0;font:15px sans-serif;vertical-align:top}.lsb:active{background:#dadce0}.lst:focus{outline:none}.Ucigb{width:458px}</style><script nonce="undWibf7tMwnEHLfrZmdxg">(function(){window.google.erd={jsr:1,bv:2336,de:true,dpf:'IcYn0n24vW1khPYWKhwfepY7J4bRuJaP2enu0IbWYh4'};
# var g=this||self;var k,l=(k=g.mei)!=null?k:1,m,p=(m=g.diel)!=null?m:0,q,r=(q=g.sdo)!=null?q:!0,t=0,u,w=google.erd,x=w.jsr;google.ml=function(a,b,d,n,e){e=e===void 0?2:e;b&&(u=a&&a.message);d===void 0&&(d={});d.cad="ple_"+google.ple+".aple_"+google.aple;if(google.dl)return google.dl(a,e,d,!0),null;b=d;if(x<0){window.console&&console.error(a,b);if(x===-2)throw a;b=!1}else b=!a||!a.message||a.message==="Error loading script"||t>=l&&!n?!1:!0;if(!b)return null;t++;d=d||{};b=encodeURIComponent;var c="/gen_204?atyp=i&ei="+b(google.kEI);google.kEXPI&&(c+="&jexpid="+b(google.kEXPI));c+="&srcpg="+b(google.sn)+"&jsr="+b(w.jsr)+
# "&bver="+b(w.bv);w.dpf&&(c+="&dpf="+b(w.dpf));var f=a.lineNumber;f!==void 0&&(c+="&line="+f);var h=a.fileName;h&&(h.indexOf("-extension:/")>0&&(e=3),c+="&script="+b(h),f&&h===window.location.href&&(f=document.documentElement.outerHTML.split("\n")[f],c+="&cad="+b(f?f.substring(0,300):"No script found.")));google.ple&&google.ple===1&&(e=2);c+="&jsel="+e;for(var v in d)c+="&",c+=b(v),c+="=",c+=b(d[v]);c=c+"&emsg="+b(a.name+": "+a.message);c=c+"&jsst="+b(a.stack||"N/A");c.length>=12288&&(c=c.substring(0,12288));a=c;n||google.log(0,"",a);return a};window.onerror=function(a,b,d,n,e){u!==a&&(a=e instanceof Error?e:Error(a),d===void 0||"lineNumber"in a||(a.lineNumber=d),b===void 0||"fileName"in a||(a.fileName=b),google.ml(a,!1,void 0,!1,a.name==="SyntaxError"||a.message.substring(0,11)==="SyntaxError"||a.message.indexOf("Script error")!==-1?3:p));u=null;r&&t>=l&&(window.onerror=null)};})();</script></head><body bgcolor="#fff"><script nonce="undWibf7tMwnEHLfrZmdxg">(function(){var src='/images/nav_logo229.png';var iesg=false;document.body.onload = function(){window.n && window.n();if (document.images){new Image().src=src;}
# if (!iesg){document.f&&document.f.q.focus();document.gbqf&&document.gbqf.q.focus();}
# }
# })();</script><div id="mngb"><div id=gbar><nobr><b class=gb1>&#44160;&#49353;</b> <a class=gb1 href="https://www.google.com/imghp?hl=ko&tab=wi">&#51060;&#48120;&#51648;</a> <a class=gb1 href="https://maps.google.co.kr/maps?hl=ko&tab=wl">&#51648;&#46020;</a> <a class=gb1 href="https://play.google.com/?hl=ko&tab=w8">Play</a> <a class=gb1 href="https://www.youtube.com/?tab=w1">YouTube</a> <a class=gb1 href="https://news.google.com/?tab=wn">&#45684;&#49828;</a> <a class=gb1 href="https://mail.google.com/mail/?tab=wm">Gmail</a> <a class=gb1 href="https://drive.google.com/?tab=wo">&#46300;&#46972;&#51060;&#48652;</a> <a class=gb1 style="text-decoration:none" href="https://www.google.co.kr/intl/ko/about/products?tab=wh"><u>&#45908;&#48372;&#44592;</u> &raquo;</a></nobr></div><div id=guser width=100%><nobr><span id=gbn class=gbi></span><span id=gbf class=gbf></span><span id=gbe></span><a href="http://www.google.co.kr/history/optout?hl=ko" class=gb4>&#50937; &#44592;&#47197;</a> | <a  href="/preferences?hl=ko" class=gb4>&#49444;&#51221;</a> | <a target=_top id=gb_70 href="https://accounts.google.com/ServiceLogin?hl=ko&passive=true&continue=https://www.google.com/&ec=GAZAAQ" class=gb4>&#47196;&#44536;&#51064;</a></nobr></div><div class=gbh style=left:0></div><div class=gbh style=right:0></div></div><center><br clear="all" id="lgpd"><div id="XjhHGf"><img alt="Google" height="92" src="/images/branding/googlelogo/1x/googlelogo_white_background_color_272x92dp.png" style="padding:28px 0 14px" width="272" id="hplogo"><br><br></div><form action="/search" name="f"><table cellpadding="0" cellspacing="0"><tr valign="top"><td width="25%">&nbsp;</td><td align="center" nowrap=""><input name="ie" value="ISO-8859-1" type="hidden"><input value="ko" name="hl" type="hidden"><input name="source" type="hidden" value="hp"><input name="biw" type="hidden"><input name="bih" type="hidden"><div class="ds" style="height:32px;margin:4px 0"><div style="position:relative;zoom:1"><input class="lst Ucigb" style="margin:0;padding:5px 8px 0 6px;vertical-align:top;color:#1f1f1f;padding-right:38px" autocomplete="off" value="" title="Google &#44160;&#49353;" maxlength="2048" name="q" size="57"><img src="/textinputassistant/tia.png" style="position:absolute;cursor:pointer;right:5px;top:4px;z-index:300" data-script-url="/textinputassistant/13/ko_tia.js" id="tsuid_haIyaejaFenJkPIPtaez0AY_1" alt="" height="23" width="27"><script nonce="undWibf7tMwnEHLfrZmdxg">(function(){var id='tsuid_haIyaejaFenJkPIPtaez0AY_1';document.getElementById(id).onclick = function(){var s = document.createElement('script');s.src = this.getAttribute('data-script-url');document.body.appendChild(s);};})();</script></div></div><br style="line-height:0"><span class="ds"><span class="lsbb"><input class="lsb" value="Google &#44160;&#49353;" name="btnG" type="submit"></span></span><span class="ds"><span class="lsbb"><input class="lsb" id="tsuid_haIyaejaFenJkPIPtaez0AY_2" value="I&#8217;m Feeling Lucky" name="btnI" type="submit"><script nonce="undWibf7tMwnEHLfrZmdxg">(function(){var id='tsuid_haIyaejaFenJkPIPtaez0AY_2';document.getElementById(id).onclick = function(){if (this.form.q.value){this.checked = 1;if (this.form.iflsig)this.form.iflsig.disabled = false;}
# else top.location='/doodles/';};})();</script><input value="AOw8s4IAAAAAaTKwlUlqtuSyL2tMfG2Dd7O8NhZ4EVsz" name="iflsig" type="hidden"></span></span></td><td class="fl sblc" align="left" nowrap="" width="25%"><a href="/advanced_search?hl=ko&amp;authuser=0">&#44256;&#44553;&#44160;&#49353;</a></td></tr></table><input id="gbv" name="gbv" type="hidden" value="1"><script nonce="undWibf7tMwnEHLfrZmdxg">(function(){var a,b="1";if(document&&document.getElementById)if(typeof XMLHttpRequest!="undefined")b="2";else if(typeof ActiveXObject!="undefined"){var c,d,e=["MSXML2.XMLHTTP.6.0","MSXML2.XMLHTTP.3.0","MSXML2.XMLHTTP","Microsoft.XMLHTTP"];for(c=0;d=e[c++];)try{new ActiveXObject(d),b="2"}catch(h){}}a=b;if(a=="2"&&location.search.indexOf("&gbv=2")==-1){var f=google.gbvu,g=document.getElementById("gbv");g&&(g.value=a);f&&window.setTimeout(function(){location.href=f},0)};}).call(this);</script></form><div style="font-size:83%;min-height:3.5em"><br></div><span id="footer"><div style="font-size:10pt"><div style="margin:19px auto;text-align:center" id="WqQANb"><a href="/intl/ko/ads/">&#44305;&#44256;</a><a href="http://www.google.co.kr/intl/ko/services/">&#48708;&#51592;&#45768;&#49828; &#49556;&#47336;&#49496;</a><a href="/intl/ko/about.html">Google &#51221;&#48372;</a><a href="https://www.google.com/setprefdomain?prefdom=KR&amp;prev=https://www.google.co.kr/&amp;sig=K_h3U1_tJuQ9PRnJ7GkcK0LxCGBbs%3D">Google.co.kr</a></div></div><p style="font-size:8pt;color:#636363">&copy; 2025 - <a href="/intl/ko/policies/privacy/">&#44060;&#51064;&#51221;&#48372;&#52376;&#47532;&#48169;&#52840;</a> - <a href="/intl/ko/policies/terms/">&#50557;&#44288;</a></p></span></center><script nonce="undWibf7tMwnEHLfrZmdxg">(function(){window.google.cdo={height:757,width:1440};(function(){var a=window.innerWidth,b=window.innerHeight;if(!a||!b){var c=window.document,d=c.compatMode=="CSS1Compat"?c.documentElement:c.body;a=d.clientWidth;b=d.clientHeight}if(a&&b&&(a!=google.cdo.width||b!=google.cdo.height)){var e=google,f=e.log,g="/client_204?&atyp=i&biw="+a+"&bih="+b+"&ei="+google.kEI,h="",k=window.google&&window.google.kOPI||null;k&&(h+="&opi="+k);f.call(e,"","",g+h)};}).call(this);})();(function(){google.xjs={basecomb:'/xjs/_/js/k\x3dxjs.hp.en.AW6aQhVgWOU.es5.O/ck\x3dxjs.hp.Yae08jK4Z7w.L.X.O/am\x3dACEAAAAAAAAAAAIAAAAAAAAAAAAAAAAAAAAAAAAAAAAEAAAAAAQEAgAAAAAAAAAAAAAAAAAAAIAAAAAAACIMAACgAIAQAAAAAAAEAAABAAAAAAAJAIQABAAAEN8RAAAAQAAsAgAAAAC8/d\x3d1/ed\x3d1/dg\x3d0/ujg\x3d1/rs\x3dACT90oFWD5JKqV1zd79C9OhI8_3kNoZDEg',basecss:'/xjs/_/ss/k\x3dxjs.hp.Yae08jK4Z7w.L.X.O/am\x3dACEAAAAAAAAAAAIAAAAAAAAAAAAAAAAAAAAAAAAAAAAEAAAAAAQAAgAAAAAAAAAAAAAAAAAAAAAAAAAAAAIAAACgAIAQAAAAAAAEAAABAAAAAAAJAIQABA/rs\x3dACT90oHJdEBDH4IoTlOLPO21FJqGb6g-WA',basejs:'/xjs/_/js/k\x3dxjs.hp.en.AW6aQhVgWOU.es5.O/am\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAEAAAAAAAAAAAAAAAAAAAAAIAAAAAAACAMAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAEN8RAAAAQAAsAgAAAAC8/dg\x3d0/rs\x3dACT90oHuHG7WsIrKXjms4UbSQZ-9lME3rw',excm:[]};})();(function(){var u='/xjs/_/js/k\x3dxjs.hp.en.AW6aQhVgWOU.es5.O/am\x3dAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAEAAAAAAAAAAAAAAAAAAAAAIAAAAAAACAMAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAAEN8RAAAAQAAsAgAAAAC8/d\x3d1/ed\x3d1/dg\x3d4/rs\x3dACT90oHuHG7WsIrKXjms4UbSQZ-9lME3rw/m\x3dsb_he,d';var st=1;var amd=1000;var mmd=0;var pop=true;var povp=false;var fp='';var ecb=false;var cst=true;var pxp=false;
# var f=this||self;function g(){var a=google.ia&&google.ia.r.B2Jtyd;return a&&[1,5,6].indexOf(a.m)>=0&&a.cbfd&&a.cbvi?a:void 0};function h(a){var b=document.createElement("link");b.as="script";b.href=a;b.rel="preload";document.body.appendChild(b)}function k(){var a=[l];google.dp||(a.forEach(h),google.dp=!0)};google.ps=google.ps||[];function m(a){var b=l,c=function(){};google.lx=google.stvsc?c:function(){n(b,a);google.lx=c};google.bx||google.lx()}function p(a,b){b&&(a.src=b);fp&&google.caft&&google.caft(function(){a.fetchPriority=fp});var c=a.onload;a.onload=function(e){c&&c(e);google.ps=google.ps.filter(function(d){return a!==d})};google.ps.push(a);document.body.appendChild(a)}function q(a,b,c){b?requestAnimationFrame(function(){p(a,c)}):p(a,c)}google.as=p;function n(a,b){google.tick&&google.tick("load","xjsls");var c=document.createElement("script");c.onerror=function(){google.ple=1};c.onload=function(){google.ple=0};google.xjsus=void 0;q(c,b,a);google.aple=-1;google.dp=!0};function r(){for(var a=document.getElementsByTagName("img"),b=0,c=a.length;b<c;b++){var e=a[b],d;if(d=e.hasAttribute("data-lzy_")&&Number(e.getAttribute("data-atf"))&1)d=e.getAttribute("jscontroller"),d=!((d==="UBXHI"||d==="R3fhkb"||d==="TSZEqd")&&e.hasAttribute("data-src"));if(d)return!0}return!1};var l,t,w,x,y,z,A,B,C,D,E="";function F(){l=pxp&&google.xjsup||u;var a=l.match("/cb=(loaded_h_\\d+)");a&&a[1]&&(E=a[1]);google.xjsu=l;f._F_jsUrl=l;z=function(c){m(c)};t=!1;w=(st===1||st===3)&&!!google.caft&&!r();x=g();y=!E&&(st===2||st===3)&&!!x&&!r();if(E){var b=(st===2||st===3)&&!!x;f[E]=function(c){var e=!1,d=function(){e||(e=!0,cst?setTimeout(function(){return void c.call(window,window._)},0):c.call(window,window._))};b&&google.ia.adls?(x.cbvi.push(function(){delete google.ia.adls}),x.cbvi.push(d),setTimeout(d,mmd)):d()}}A=
# pop;B=povp;C=A&&document.prerendering||B&&document.hidden;D=B?"visibilitychange":"prerenderingchange"}function G(a){t||w||y||C||(z(a),t=!0)}
# setTimeout(function(){google.tick&&google.tick("load","xjspls");F();if(w||y||C){if(w){var a=function(){w=!1;G()};google.caft(a);setTimeout(a,amd)}y&&(a=function(){y=!1;G()},x.cbvi.push(a),setTimeout(a,mmd));if(C){var b=function(){(B?document.hidden:document.prerendering)||(C=!1,G(!B&&!1),document.removeEventListener(D,b))};document.addEventListener(D,b,{passive:!0})}t||k()}else z()},0);})();window._ = window._ || {};window._DumpException = _._DumpException = function(e){throw e;};window._s = window._s || {};_s._DumpException = _._DumpException;window._qs = window._qs || {};_qs._DumpException = _._DumpException;window.loaded_h_0 = function(cb){cb.call(window,window._);};(function(){var t=[8448,0,2097152,0,0,0,0,0,1310720,268435456,4204768,0,16,0,134217728,187039744,548151816,163844,268435720,16844848,65536,0,138412176,256,1171216,16777216,8900,788529152];window._F_toggles = window._xjs_toggles = t;})();window._F_installCss = window._F_installCss || function(css){};(function(){google.jl={bfl:0,dw:false,eli:false,ine:false,ubm:false,uwp:true,vs:false};})();(function(){var pmc='{\x22csies\x22:{},\x22d\x22:{},\x22sb_he\x22:{\x22client\x22:\x22heirloom-hp\x22,\x22dh\x22:true,\x22ds\x22:\x22\x22,\x22host\x22:\x22google.com\x22,\x22jsonp\x22:true,\x22msgs\x22:{\x22cibl\x22:\x22\\uac80\\uc0c9\\uc5b4 \\uc9c0\\uc6b0\\uae30\x22,\x22dym\x22:\x22\\uc774\\uac83\\uc744 \\ucc3e\\uc73c\\uc168\\ub098\\uc694?\x22,\x22lcky\x22:\x22I\\u2019m Feeling Lucky\x22,\x22lml\x22:\x22\\uc790\\uc138\\ud788 \\uc54c\\uc544\\ubcf4\\uae30\x22,\x22psrc\x22:\x22\\uac80\\uc0c9\\uc5b4\\uac00 \\u003Ca href\x3d\\\x22/history\\\x22\\u003E\\uc6f9 \\uae30\\ub85d\\u003C/a\\u003E\\uc5d0\\uc11c \\uc0ad\\uc81c\\ub418\\uc5c8\\uc2b5\\ub2c8\\ub2e4.\x22,\x22psrl\x22:\x22\\uc0ad\\uc81c\x22,\x22sbit\x22:\x22\\uc774\\ubbf8\\uc9c0\\ub85c \\uac80\\uc0c9\x22,\x22srch\x22:\x22Google \\uac80\\uc0c9\x22},\x22ovr\x22:{},\x22pq\x22:\x22\x22,\x22rfs\x22:[],\x22stok\x22:\x22xA6SdxUT4X1l-a9RRvpePFEjDn8\x22}}';google.pmc=JSON.parse(pmc);})();</script></body></html>
# 18812
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="ko"><head><meta content

# %%
# --- 3. "Naver 요청 및 응답 분석" (Naver Request and Analysis) ---


# Naver 홈페이지의 URL을 'url' 변수에 저장합니다.
url = 'http://www.naver.com'

# Naver로 HTTP GET 요청을 보내고, Response 객체를 'res' 변수에 저장합니다.
res = requests.get(url)

# Response 객체의 "status_code"를 출력합니다. ("200"이면 성공)
print(res.status_code)

# Response 객체의 "text" 속성(HTML 소스 코드 전체)을 출력합니다.
print(res.text)

# HTML 소스 코드 문자열의 "총 길이"를 출력합니다.
print(len(res.text))
# Out:
# 200
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="google-site-verification" content="uru5NJKa1Bfr5nv5AdQ26Qat7UrPU_02l-PIZRLzI-g"/> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"> <link rel="apple-touch-icon-precomposed" href="https://s.pstatic.net/static/www/nFavicon96.png"/> <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_251001.css"> <link rel="canonical" href="https://www.naver.com/"> <link rel="alternate" media="only screen and (max-width: 767px)" href="https://m.naver.com/"> <script>window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"</script> <script>window.ntm=window.ntm||[]</script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script src="https://ssl.pstatic.net/tveta/libs/assets/js/pc/main/min/pc.veta.core.min.js" defer="defer"></script>  <script>
# window["EAGER-DATA"] = window["EAGER-DATA"] || {};
# window["EAGER-DATA"]["PC-FEED-WRAPPER"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-CAS-EDIT-CONTENTS-BLOCK","blocks":null,"materials":[{"@type":"MATERIAL-PC-FEED-EDIT","title":"인기 유아 도서부터 잡지 정기구독까지","url":"https://shopping.naver.com/festa/onsale/play/691d833bf637a03670c8b8b1","image":{"url":"https://s.pstatic.net/static/www/mobile/edit/20251202_1095/upload_1764663443269y6PIR.jpg"},"highlight":"강세일","title2":"기간 한정, 단독 할인 판매","source":{"name":"더 자세한 내용 만나보기"},"_id":"692c612dc3042ec88ac627b7"},{"@type":"MATERIAL-PC-FEED-EDIT","title":"넷플릭스 인기 시리즈","url":"https://smartstore.naver.com/amazonkids/products/12774296177","image":{"url":"https://s.pstatic.net/static/www/mobile/edit/20251204_1095/upload_1764832302732ZRwC3.png"},"highlight":"예약판매","title2":"멜로무비 대본집 출간","source":{"name":"더 자세한 내용 만나보기"},"_id":"692c612dc3042ec88ac627b8"}],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"layout":"BIG-IMAGE-2","orderRandom":false,"_id":null,"@type":"PC-CAS-EDIT-CONTENTS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":"PC-FEED-CULTURE-CAS-EDIT","@template":"PC-FEED-CAS-EDIT","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-FEED-BLOCK","materials":[{"@type":"MATERIAL-PC-FEED","title":"나노 바나나","url":"https://msearch.shopping.naver.com/book/catalog/57259885634","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5725988%2F57259885634.20251017092849.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"문수민, 박범희, 앤미디어","service":"생능북스"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b727"},{"@type":"MATERIAL-PC-FEED","title":"영어 회화 패턴 훈련 1차 임계점","url":"https://msearch.shopping.naver.com/book/catalog/57394991333","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5739499%2F57394991333.20251028075351.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"신원섭, Diana Salazar","service":"사람in"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b728"},{"@type":"MATERIAL-PC-FEED","title":"포인트 캐릭터 드로잉 2","url":"https://msearch.shopping.naver.com/book/catalog/57435145183","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5743514%2F57435145183.20251031071036.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"타코","service":"레진엔터테인먼트"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b729"},{"@type":"MATERIAL-PC-FEED","title":"오프 먼트","url":"https://msearch.shopping.naver.com/book/catalog/57237579405","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5723757%2F57237579405.20251107092428.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"장재열","service":"큰숲"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b72a"},{"@type":"MATERIAL-PC-FEED","title":"괴테는 모든 것을 말했다","url":"https://msearch.shopping.naver.com/book/catalog/57717256176","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5771725%2F57717256176.20251111092028.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"스즈키 유이","service":"리프"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b72b"},{"@type":"MATERIAL-PC-FEED","title":"도파민 세대를 위한 문해력 특강","url":"https://msearch.shopping.naver.com/book/catalog/57537373621","image":{"url":"https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fshopping.phinf%2Fmain_5753737%2F57537373621.20251104085950.jpg%22&type=nf216_312&service=navermain"},"source":{"name":"이승화","service":"문예춘추사"},"showLiveBadge":false,"_id":"660a0b5d0f404c1848d9b72c"},{"@type":"MATERIAL-PC-FEED","title":"2026 국어 2차 수업실연 순식간에 정복하기(임용 2차 시험대비)","url":"ht ...
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8e3a10d3006850274e8","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SPECIAL-LOGO","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"685cce7d-d1ba-11f0-8fcf-111924a3d431","@provider":"lambda","@lastModifiedAt":[2025,12,5,9,11,39,389000000]}
# window["EAGER-DATA"]["PC-MEDIA-WRAPPER"] = {"@type":"PC-MEDIA-CONTENTS-BLOCK","blocks":[{"@type":"BLOCK","blocks":[{"@type":"PC-NEWSSTAND-BLOCK","blocks":[{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"907","name":"경북매일신문","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/907.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/907.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251205 17:47:42","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"908","name":"국방일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/908.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/908.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251204 17:46:50","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"909","name":"기호일보","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/909.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/909.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251205 17:51:03","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"353","name":"중앙SUNDAY","logoLight":{"url":"https://s.pstatic.net/static/newsstand/up/2025/0418/nsd181433494.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/up/2025/0418/nsd181453897.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251204 10:54:38","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"354","name":"엘르","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/354.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/354.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251205 18:05:11","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"355","name":"사이언스타임즈","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/355.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/355.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251205 10:03:30","_id":null,"@type":"PC-NEWSSTAND-PRESS-BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null},{"@type":"PC-NEWSSTAND-PRESS-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"pid":"356","name":"게임메카","logoLight":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/light/0604/356.png"},"logoDark":{"url":"https://s.pstatic.net/static/newsstand/2020/logo/dark/0604/356.png"},"showThumbnailView":true,"showListView":true,"regDate":"20251205 17:14:33","_id":null,"@type":"PC-N ...
# window["EAGER-DATA"]["PC-NEWSSTAND-YONHAP"] = {"@type":"BLOCK","blocks":[{"@type":"BLOCK","blocks":null,"materials":[],"excludeInPaging":false,"positionForPaging":0,"realtime":false,"_id":null,"@type":"BLOCK","@code":null,"@template":"NONE","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}],"materials":[{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"정청래표 '1인1표제' 좌초…與중앙위서 당헌개정안 전격 부결","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015781842","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"643543b2caf3d87b7e0a0da6"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"'기강 잡기' 나선 李대통령…공직사회 동요·불만 차단 포석","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015781817","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec43489"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"李대통령 \"지역통합, 될 듯하다 안 돼…정치적 이해충돌 탓\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015781496","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348a"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"\"장동혁 변해야\" 점점 커지는 국힘內 압박…중도 외연확장 요구","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015781728","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348b"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"'내란재판부·법왜곡죄' 법원장회의 시작…조희대 \"개편 신중히\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015781311","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"677344ca0dae05b66ec4348c"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"尹 '한덕수 재판 위증' 추가기소, 이상민 내란사건 재판부에","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015781809","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"683f13f2f74934e40c0fed6b"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"쿠팡 이용자 나흘 만에 감소…지마켓·11번가·네이버는 증가","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015781823","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"68db37e6cdff968ea897472f"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"교육부, '불'영어 논란에 \"출제·검토 과정 조사…엄정 대응\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015781831","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"68db3a029fd064e40518502f"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"7년전 학폭·성폭행에 중형 구형…피해자 \"이젠 나아갈 수 있게\"","url":"https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&sid1=001&sid2=140&oid=001&isYeonhapFlash=Y&aid=0015781447","aid":null,"emergency":false,"notCompleted":false,"officeName":"연합뉴스","officeId":"001","officeHomeUrl":null,"officeWeight":0,"officeWeightRate":0.0,"_id":"6932829ed27bbfaa946449de"},{"@type":"MATERIAL-PC-NEWS-ONELINE","gdid":null,"title":"트럼프, 월드컵 조추첨도 정치무대로…FI ...
# window["EAGER-DATA"]["PC-PREMIUM-AD"] = {"@type":"PC-PREMIUM-AD-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"adResponse":{"type":"N010","adlineId":null,"vimp100p0s":null,"assets":null,"vimp50p1s":"https://siape.veta.naver.com/fxview?eu=EU10044434&calp=-&oj=UDLDkoMX9MNQsbHfqBkowgPrgHibyohQ%2FOr5cIjh%2B5Vp8CTTXrCk1iGNcbrnFmKn&ac=8206821&src=4733402&evtcd=V900&x_ti=1362&tb=&oid=&sid1=&sid2=&rk=DHguhLg3FSc9CU-rtFx5Hw&eltts=JcqC9KLxjBijSr6Krc%2F7Sg%3D%3D&brs=Y&&eid=V900"},"_id":null,"@type":null,"@code":"PC-PREMIUM-AD","@template":"PC-PREMIUM-AD","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}
# window["EAGER-DATA"]["PC-MYSERVICE-META"] = {"@type":"PC-MYSREVICE-META","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"serviceMetaList":[],"_id":"68414a73a10d30068523e7ee","@type":"MY-SERVICE-META-BLOCK","@code":"PC-MYSERVICE-META","@template":"NONE","@flowId":"PC-MYSERVICE-META","@flowExecutionId":"7e6b2a92-d1ba-11f0-887b-a5a62be6895b","@provider":"lambda","@lastModifiedAt":[2025,12,5,9,12,16,382000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-SEARCH-RIGHT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"6433d8a5a10d300685012682","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-SEARCH-RIGHT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"67022074-d1ba-11f0-8fcf-e5c1c8bb41be","@provider":"lambda","@lastModifiedAt":[2025,12,5,9,11,37,101000000]}
# window["EAGER-DATA"]["PC-HEADLINE-AD"] = {"@type":"PC-HEADLINE-AD-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"adResponse":{"type":"N011","adlineId":null,"vimp100p0s":"https://siape.veta.naver.com/fxview?eu=EU10044129&calp=-&oj=ZJlEFeSBKmLf40n3ktJ9%2FAPrgHibyohQ%2FOr5cIjh%2B5Vp8CTTXrCk1iGNcbrnFmKn&ac=8968387&src=7094288&evtcd=V900&x_ti=1586&tb=&oid=&sid1=&sid2=&rk=J6_dvHAw6R_KVhKModjmBA&eltts=JcqC9KLxjBijSr6Krc%2F7Sg%3D%3D&brs=Y&&eid=V900","assets":null},"_id":null,"@type":null,"@code":"PC-HEADLINE-AD","@template":"PC-HEADLINE-AD","@flowId":null,"@flowExecutionId":null,"@provider":null,"@lastModifiedAt":null}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MEDIA-TAB-EVENT"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"643687e1a10d300685630556","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MEDIA-TAB-EVENT","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"6e52aee0-d1ba-11f0-a340-9566925a4ab5","@provider":"lambda","@lastModifiedAt":[2025,12,5,9,11,49,381000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-MID-BANNER"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[],"_id":"648ae476a10d300685fbab10","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-MID-BANNER","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"875bd579-d1ba-11f0-8fcf-4d33f3679720","@provider":"lambda","@lastModifiedAt":[2025,12,5,9,12,31,379000000]}
# window["EAGER-DATA"]["CAS-MINICONTENT-PC-TAB-META"] = {"@type":"MINI-CONTENT-BLOCK","blocks":null,"materials":null,"excludeInPaging":false,"positionForPaging":0,"realtime":false,"items":[{"content":{"area":"FEED","tabList":[{"clickCode":"tct.mynr","name":"추천・구독","id":"PC-FEED-RECOMMEND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.wtn","name":"자동차","id":"PC-FEED-CARGAME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.wtn","name":"웹툰","id":"PC-FEED-WEBTOON","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bty","name":"패션뷰티","id":"PC-FEED-BEAUTY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.fod","name":"레시피","id":"PC-FEED-RECIPE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lif","name":"리빙","id":"PC-FEED-LIVINGHOME","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.bok","name":"책방","id":"PC-FEED-CULTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.lec","name":"지식+","id":"PC-FEED-LECTURE","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":true,"weight":1},{"clickCode":"tct.health","name":"건강","id":"PC-FEED-HEALTH","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"tct.gameapp","name":"게임","id":"PC-FEED-GAMEAPP","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e64d370a065058f369bac","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-10 00:00","@endAt":"2030-05-30 23:59","@createdAt":"2023-04-18T18:37:23.412","@updatedAt":"2023-11-08T11:34:03.902"},{"content":{"area":"MEDIA","tabList":[{"clickCode":"nst.nsd","name":"뉴스스탠드","id":"PC-MEDIA-NEWSSTAND","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.nch","name":"언론사편집","id":"PC-MEDIA-NEWS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.ent","name":"엔터","id":"PC-MEDIA-ENTER","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.spo","name":"스포츠","id":"PC-MEDIA-SPORTS","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.fin","name":"경제","id":"PC-MEDIA-ECONOMIC","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1},{"clickCode":"nst.shpt","name":"쇼핑투데이","id":"PC-MEDIA-SHOPPING-TODAY","contingencyEnabled":true,"enabled":true,"useFeedCasEditTemplate":false,"weight":1}],"@type":"BLOCK-PC-TAB-META"},"exposure":true,"@miniContentId":"643e642c8793487c84743a38","@miniContentCode":"PC-TAB-META","@startAt":"2023-04-11 00:00","@endAt":"2030-05-31 23:59","@createdAt":"2023-04-18T18:34:36.648","@updatedAt":"2024-04-18T16:13:27.109"}],"_id":"643e6299a10d3006853cc04c","@type":"MINI-CONTENT-BLOCK","@code":"CAS-MINICONTENT-PC-TAB-META","@template":"NONE","@flowId":"CAS-MINICONTENT","@flowExecutionId":"708d3560-d1ba-11f0-8fcf-dbecca2441b2","@provider":"lambda","@lastModifiedAt":[2025,12,5,9,11,53,120000000]}
# </script>
#
#
#  <script defer="defer" src="https://pm.pstatic.net/resources/js/polyfill.de9c70b5.js?o=www" crossorigin="anonymous"></script><script defer="defer" src="https://pm.pstatic.net/resources/js/preload.baeef60d.js?o=www" crossorigin="anonymous"></script><script defer="defer" src="https://pm.pstatic.net/resources/js/search.1c8f328c.js?o=www" crossorigin="anonymous"></script><script defer="defer" src="https://pm.pstatic.net/resources/js/main.7e291fda.js?o=www" crossorigin="anonymous"></script><link href="https://pm.pstatic.net/resources/css/main.07f20d10.css" rel="stylesheet"></head> <body> <div id="u_skip"> <a href="#topAsideButton"><span>상단영역 바로가기</span></a> <a href="#shortcutArea"><span>서비스 메뉴 바로가기</span></a> <a href="#newsstand"><span>새소식 블록 바로가기</span></a> <a href="#shopping"><span>쇼핑 블록 바로가기</span></a> <a href="#feed"><span>관심사 블록 바로가기</span></a> <a href="#account"><span>MY 영역 바로가기</span></a> <a href="#widgetboard"><span>위젯 보드 바로가기</span></a> <a href="#viewSetting"><span>보기 설정 바로가기</span></a> </div>   <script type="text/plain" id="ad-timeboard-response" data-gfp-banner-size="830x130" data-gfp-banner-type="full">{"payload":{"requestId":"1ce2bfeed9e440459eac92814843d9cc","head":{"version":"0.0.1","description":"Naver SSP Waterfall List"},"eventTracking":{"ackImpressions":[{"url":"https://tivan.naver.com/sc2/1/"}],"activeViewImpressions":[{"url":"https://tivan.naver.com/sc2/2/"}],"clicks":[{"url":"https://tivan.naver.com/sc2/3/"}],"completions":[{"url":"https://tivan.naver.com/sc2/4/"}],"attached":[{"url":"https://tivan.naver.com/sc2/10/"}],"renderedImpressions":[{"url":"https://tivan.naver.com/sc2/11/"}],"viewableImpressions":[{"url":"https://tivan.naver.com/sc2/12/"}],"loadErrors":[{"url":"https://tivan.naver.com/sc2/91/"}],"startErrors":[{"url":"https://tivan.naver.com/sc2/92/"}],"lazyRenderMediaFailed":[{"url":"https://tivan.naver.com/sc2/93/"}],"mute":[{"url":"https://tivan.naver.com/sc2/5/"}],"close":[{"url":"https://tivan.naver.com/sc2/6/"}]},"adUnit":"p_main_timeboard_v1","randomNumber":67,"adDivId":"ad_timeboard","advertiserDomains":["www.navercorp.com"],"adDuplicationKeys":["URL:https://www.navercorp.com/"],"ads":[{"encrypted":"ZgNLrNkTeDR4lrp7rAF8dEFXFYbbHSHyNKCcl69LwxUS77G1GVkSbOSddM6q4I4_nsw3kmc9wVPWxOPd64Y7ps9_I41VtJFpUeF1Ty1h6l-SV6XXYFne8HoZFTCXacP63id7yjIMGdqVU1hpgHPErLr4QEG-SM8eR5KNEdgFl0wvUXgClfLrlhYzEU789jjpn0Bobg07U57WIC3dez3ra5UeLWNVfyLohv3toskA-C_Yl3xRKNXWSTLDL0XXPuCtLub84WIS34qBggYGmg0ZwuC4uGofPPj2qumgnl19enjpQ2Xulpihy585IgBO9CIurpvklg9whsRQZ0Eb-4wOkkG11msgsv_uEp4_hN15Cr3npB1S0MJMzftPk-1G3H_eH6LkPK0IbB2fg2vljped6tXzcVTVSdpzwmjoopLjEKaOyNqv3euLfg56eiaoghtWBzEvUsMk1BzU7tpblG7nZbYnyNn87GD1GUNQ8SJDfAPY-cR_wLpjxs5YOKC01EG3kigrlITUeM7RVb8DZOfvfxUz--Xq3HUn4BmUV9q3O2lqfhe-k7fEg1OOV7UEQYpByB48VxjXEP4fI_vpcvDMUIu15Om9TZNZcr3s3rlE9cIdzHq4MCDok8NGVw6iPWA-Wzt6Tz1WO5HMCXbHK7KO03PyBJKJqODlHbbC4bh9Bb8hdOUSp1jL3Ebh1EZ-bkgYJ_FXwv4oOKoQZnFWnOLgKVUcuBdBopQB9qph5lcIQyE=","connectionType":"S2S","adProviderType":"IN_NAVER","adProviderName":"NDP_SF","layoutType":"FLUID","creativeType":"BANNER","renderType":"SF","eventTracking":{"ackImpressions":[{"url":"https://siape.veta.naver.com/openrtb/nurl?eu=EU10043565\u0026calp=-\u0026oj=cQgn6aire5PNh6Tw40D0SkuEyLEZwhFxGA5laJoIKr7PFjDw99zt8vnLedBMrnxxJL1qM2Pf%2FakD64B4m8qIUPzq%2BXCI4fuVafAk016wpNaeBJzbEUemkkplqdgUSG%2BUXrQSw%2B%2FX1bbNCF9%2F110BZDp0hCNKO%2BcHo2M9jEOAPSLbaIdXv9YIFqKzdZWOwZvb10wXXPTxP9fUvtBMhB%2F95FF8ugsnigZsy9gvmfFyhM0\u0026ac=9220411\u0026src=7915357\u0026evtcd=BID_WIN\u0026x_ti=1504\u0026rk=VG3LZDopEbMew6rLvPY2zQ\u0026eltts=JcqC9KLxjBijSr6Krc%2F7Sg%3D%3D\u0026brs=Y\u0026"}],"attached":[],"activeViewImpressions":[],"renderedImpressions":[],"viewableImpressions":[],"clicks":[],"vimp1px":[],"vimp100":[],"vimp100p":[],"admute":[],"advmute":[],"like":[],"unlike":[],"close":[],"bounce":[],"priv":[]},"adInfo":{"placeId":"6436232db28a76002ea3f30c","adomain":["www.navercorp.com"],"cid":"1553176","crid":"2818364","exp":86400,"adContext":"{\"id\":\"1ce2bfeed9e440459eac92814843d9cc\",\" ...
# </script> <div id="wrap"> <div id="header" role="banner"> <div id="topSearchWrap" class="header_inner"> <div id="special-logo" class="search_special_bg"></div> <div id="timeboard-ex" class="ad_area" style="width:1280px"> </div> <div id="search_area" class="search_area" style="border-color:#fff"> <div class="search_group"> <div id="search" class="search_group_inner"> <h1 id="special-input-logo" class="search_logo"></h1> <form id="sform" name="search" role="search" action="https://search.naver.com/search.naver" method="get"> <fieldset> <legend class="blind">검색</legend> <input type="hidden" name="where" value="nexearch"/> <input type="hidden" id="sm" name="sm" value="top_hty"/> <input type="hidden" id="fbm" name="fbm" value="0"/> <input type="hidden" id="acr" name="acr" value="" disabled="disabled"/> <input type="hidden" id="acq" name="acq" value="" disabled="disabled"/> <input type="hidden" id="qdt" name="qdt" value="" disabled="disabled"/> <input type="hidden" id="ie" name="ie" value="utf8"/> <input type="hidden" id="acir" name="acir" value="" disabled="disabled"/> <input type="hidden" id="os" name="os" value="" disabled="disabled"/> <input type="hidden" id="bid" name="bid" value="" disabled="disabled"/> <input type="hidden" id="pkid" name="pkid" value="" disabled="disabled"/> <input type="hidden" id="eid" name="eid" value="" disabled="disabled"/> <input type="hidden" id="mra" name="mra" value="" disabled="disabled"/> <div class="search_input_box"> <input id="query" type="search" name="query" class="search_input" maxlength="255" autocomplete="off" placeholder="검색어를 입력해 주세요." title="검색어를 입력해 주세요." role="combobox" aria-expanded="false" aria-haspopup="listbox" aria-owns="autoFrame" aria-controls="" aria-autocomplete="list" aria-activedescendant="" data-atcmp-element=""> </div> <button type="submit" class="btn_search" onclick='window.ntm.push({event:"nclick",el:this,click_area:"sch.action"})'> <span class="ico_btn_search_svg"> <svg id="search-btn" viewBox="0 0 50 50" xmlns="http://www.w3.org/2000/svg"> <path d="M22.13.5c11.378 0 20.632 9.256 20.632 20.63 0 4.699-1.566 9.155-4.439 12.782l10.164 10.165a2.41 2.41 0 0 1-1.706 4.115 2.412 2.412 0 0 1-1.706-.705L33.31 35.719a2.41 2.41 0 0 1 0-3.41 15.71 15.71 0 0 0 4.628-11.178c0-8.718-7.09-15.808-15.807-15.808-8.718 0-15.808 7.09-15.808 15.808 0 7.15 4.817 13.43 11.714 15.273a2.41 2.41 0 0 1 1.705 2.954 2.41 2.41 0 0 1-2.95 1.705C7.788 38.658 1.5 30.46 1.5 21.131 1.5 9.756 10.756.5 22.13.5zm4.716 34.746a3.483 3.483 0 1 1 0 6.966 3.483 3.483 0 0 1 0-6.966z"/> </svg> </span> <span class="blind">검색</span> </button> </fieldset> </form> <div class="search_box"> <button id="ke_kbd_btn" type="button" class="btn_keyboard" aria-pressed="false"> <span class="keybord_text"> <span class="blind">입력도구</span> </span> </button> <div id="_nx_kbd" style="display:none"></div> <button id="nautocomplete" type="button" class="btn_arrow" data-atcmp-element> <span class="blind">자동완성/최근검색어펼치기</span> </button> </div> <div class="layer_atcmp" id="autoFrame" style="display:none"></div> </div> </div> </div> <div id="search-right"></div> <div id="shortcutArea" class="shortcut_area" role="navigation" aria-label="주요 서비스"></div> <div id="topAsideArea" class="menu_area"></div> <div id="topPayArea" class="pay_area"></div> <div id="topTalkArea" class="talk_area"></div> <div id="topNotiArea" class="notify_area"></div> <div id="topShoppingArea" class="shopping_area"></div> </div> </div> <div id="container" role="main"> <div id="ad_premium_area" class="ad_premium_area" style="min-width:1920px"> </div> <div id="root"></div> </div> <div id="footer" role="contentinfo"></div> </div>      <script> window['EAGER-DATA'] = window['EAGER-DATA'] || {};
#         window['EAGER-DATA']['GV'] = {
#             svt: '20251205181445',  }; </script> <script>!function(){function t(t){var e=document.getElementById("search_area"),l=document.getElementById("search-btn");if(!t)return e&&e.removeAttribute("style"),void(l&&l.setAttribute("style","fill: #03c75a"));e&&e.setAttribute("style","border-color: "+t),l&&l.setAttribute("class","ico_btn_search type_color"),l&&l.setAttribute("style","fill: "+t)}var e=window["EAGER-DATA"]["CAS-MINICONTENT-PC-SPECIAL-LOGO"];if(!e||!e.items||e.items.length>0==!1)return void t();var l=Math.floor(Math.random()*e.items.length),s=e.items[l];e.items=[s];const o=s&&s.content?s.content.input:null;t(o&&o.color);const i=document.getElementById("search"),n=i&&(!o||!o.showSearchLogo);n&&i.classList.add("type_special_logo_full"),window.addEventListener("header-sticky-state-change",function(){var t;(t=document.getElementById("header"))&&t.classList.contains("ani_fixed")?n&&i.classList.remove("type_special_logo_full"):n&&i.classList.add("type_special_logo_full")});var r=o&&o.placeholder;if(r){var a=document.getElementById("query");a&&r&&a.setAttribute("title",r),a&&r&&a.setAttribute("placeholder",r)}}()</script> </body> </html>
# 202855

# %%
# --- "requests" 모듈을 이용한 GET 요청 방식 ---



# 1. "URL에 직접 파라미터 포함" 방식 (Direct Parameter in URL)

# 네이버 스포츠 뉴스의 기본 URL을 'base_url' 변수에 저장합니다.
base_url = "https://sports.news.naver.com/news" 

# 쿼리 스트링(Query String, 파라미터)이 "직접 포함된" 최종 URL을 'param_url' 변수에 저장합니다.
# '?' 뒤의 'oid=079&aid=0004089508' 부분이 서버로 전달할 데이터(파라미터)입니다.
param_url ="https://sports.news.naver.com/news?oid=079&aid=0004089508"



# "requests.get(param_url)"을 사용하여 파라미터가 포함된 전체 URL로 HTTP GET 요청을 보냅니다.
res1 = requests.get(param_url)

# Response 객체 'res1'의 "status_code"를 출력합니다.
# "200"이 출력되면 요청이 "성공적"이었음을 의미하며, 페이지 데이터를 정상적으로 받았다는 뜻입니다.
print(res1.status_code)
# Out:
# 200

# %%
# 2. "params 인수를 사용한 파라미터 전달" 방식 (Using the params Argument)


# 네이버 스포츠 뉴스의 기본 URL입니다. (쿼리 스트링은 포함하지 않습니다.)
# base_url = "https://sports.news.naver.com/news"

# 서버로 전달할 파라미터를 Python "딕셔너리" 형태로 정의합니다.
# key: value 쌍이 웹의 파라미터 이름과 값으로 매핑됩니다.
param = {'oid':'079', 'aid':'0004089508'}

# "requests.get(base_url, params=param)" 함수를 사용하여 GET 요청을 보냅니다.
# "requests" 모듈이 "base_url" 뒤에 딕셔너리 'param'의 내용을 자동으로 붙여 쿼리 스트링을 완성합니다.
# 즉, requests가 내부적으로 'base_url?oid=079&aid=0004089508' 형태의 URL을 만들어 요청합니다.
# 이 방식은 한글이나 특수문자가 포함된 파라미터 처리(URL 인코딩) 시 "매우 안전"하고 "가독성"이 좋습니다.
res2 = requests.get(base_url, params=param)

# Response 객체 'res2'의 "status_code"를 출력합니다. (역시 "200"이 예상됩니다.)
print(res2.status_code)
# Out:
# 200

# %%
# --- URL 연결 및 데이터 읽기 ---


# 1. "URL 연결 및 응답 객체 확인" (URL Connection and Response Object)

# 네이버 홈페이지의 URL을 'url' 변수에 저장합니다.
url ='http://www.naver.com'

# "urlopen(url)" 함수를 사용하여 해당 URL로 연결을 시도하고,
# 서버로부터 받은 "HTTPResponse 객체"를 'html' 변수에 저장합니다.
# 이 객체는 웹 서버와의 연결을 나타냅니다.
# ⚠️ 주의: 이 코드는 'urlopen'이 임포트되었다고 가정합니다.
html = urlopen(url)

# "HTTPResponse 객체"인 'html' 변수의 정보를 출력합니다.
# 출력 결과는 보통 <http.client.HTTPResponse object at 0x...> 형태로 나타나며,
# 이는 서버와의 연결이 성공했음을 의미합니다.
print(html)
# Out:
# <http.client.HTTPResponse object at 0x0000028B6D6F4430>

# %%
# 2. "바이너리 데이터 읽기 및 타입 확인" (Reading Binary Data and Type Check)


# 'html' 객체(HTTPResponse)의 ".read()" 메서드를 사용하여 
# 서버가 보낸 응답 본문(HTML 소스 코드) "전체"를 읽어 'rawtext'에 저장합니다.
# 웹에서 읽어온 데이터는 기본적으로 "바이너리(bytes)" 형태로 저장됩니다.
rawtext = html.read()

# 'rawtext' 변수의 "타입"을 출력합니다.
# 출력 결과는 "<class 'bytes'>"이며, 이는 데이터가 0과 1로 이루어진 "바이트 시퀀스"임을 나타냅니다.
print(type(rawtext))

# 'rawtext' 변수의 "타입"을 출력하고 줄 바꿈 문자를 추가합니다. (재확인)
print(type(rawtext),"\n")

# 'rawtext' 변수를 "bytes" 타입으로 변환(이미 bytes 타입이므로 형태 유지)하고, 
# 데이터의 "앞에서 200 바이트"까지만 잘라내어 출력합니다.
# 바이너리 데이터는 사람이 읽을 수 없는 형태로 보입니다 (예: b'<!DOCTYPE html>...').
print(bytes(rawtext)[:200], "\n")

# 'rawtext' (바이너리 데이터)를 ".decode('utf8')" 메서드를 사용하여 
# 'utf8' 인코딩 방식에 따라 "문자열(string)"로 변환합니다.
# 변환된 문자열의 "앞에서 200자"까지만 잘라내어 출력합니다.
# 이제 데이터가 사람이 읽을 수 있는 HTML 텍스트 형태로 출력됩니다.
print(rawtext.decode('utf8')[:200])


# "핵심 개념: 바이트 vs 문자열"
#  - 웹에서 데이터를 읽어오면 항상 "바이트(bytes)" 형태로 받게 됩니다.
#  - **"바이트"**는 컴퓨터가 이해하는 0과 1의 시퀀스이며, 파일 저장이나 네트워크 전송에 사용됩니다.
#  - 우리가 읽을 수 있는 텍스트로 사용하려면 .decode() 메서드를 사용하여
# 특정 인코딩(여기서는 utf8)을 통해 **"문자열(str)"**로 변환해야 합니다.
# Out:
# <class 'bytes'>
# <class 'bytes'>
#
# b'   <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" cont'
#
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" cont

# %%
# --- URL 연결, 데이터 읽기 및 BeautifulSoup 파싱 ---



# 1. "URL 연결 및 응답 객체 확인" (URL Connection and Response Object)

# 네이버 홈페이지의 URL을 'url' 변수에 저장합니다.
url = 'http://www.naver.com'

# "urlopen(url)" 함수를 사용하여 해당 URL로 연결을 시도하고,
# 서버로부터 받은 "HTTPResponse 객체"를 'html' 변수에 저장합니다.
# 이 객체는 웹 서버와의 "활성 연결"을 나타냅니다.
# 주의: 'urlopen'은 urllib.request 모듈에 속합니다.
html = urlopen(url)

# "HTTPResponse 객체"인 'html' 변수의 정보를 출력합니다.
# 출력 결과는 <http.client.HTTPResponse object at 0x...> 형태이며, 
# 이는 서버와의 연결이 "성공적"이었음을 의미합니다.
print(html)
# Out:
# <http.client.HTTPResponse object at 0x0000028B68938E80>

# %%
# 2. "BeautifulSoup 객체 생성 및 타입 확인" (BeautifulSoup Object Creation and Type Check)


# "bs4.BeautifulSoup()" 생성자를 사용하여 HTML 파싱 객체를 만듭니다.
# 첫 번째 인수인 'html' (HTTPResponse 객체)에서 HTML 데이터를 읽어옵니다.
# 두 번째 인수인 'html.parser'는 파이썬 표준 라이브러리에 포함된 "HTML 파서"를 사용하도록 지정합니다.
# 파싱된 구조화된 객체는 'bs_obj' 변수에 저장됩니다.
bs_obj = bs4.BeautifulSoup(html,'html.parser')

# 'bs_obj' 변수의 "타입"을 출력합니다.
# 출력 결과는 "<class 'bs4.BeautifulSoup'>"이며, 이는 데이터가 
# 웹 스크래핑에 용이한 "BeautifulSoup 객체"로 변환되었음을 나타냅니다.
print(type(bs_obj))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
# 3. "HTML 구조 출력" (Pretty HTML Output)

# 'bs_obj' 객체의 ".prettify()" 메서드를 호출합니다.
# 이 메서드는 파싱된 HTML 구조를 "보기 좋게 들여쓰기"하고 정렬된 문자열로 반환합니다.
# 반환된 문자열의 "앞에서 2468자"까지만 잘라내어 출력합니다.
# 이 출력은 웹페이지의 "구조화된 소스 코드"를 보여주며, 태그와 계층 구조를 쉽게 파악할 수 있게 해줍니다.
print(bs_obj.prettify()[:2468])
# Out:
# <!DOCTYPE html>
# <html class="fzoom" lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="origin" name="Referrer"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=1190" name="viewport"/>
#   <title>
#    NAVER
#   </title>
#   <meta content="NAVER" name="apple-mobile-web-app-title">
#    <meta content="index,nofollow" name="robots">
#     <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
#      <meta content="네이버" property="og:title"/>
#      <meta content="https://www.naver.com/" property="og:url"/>
#      <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
#      <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
#       <meta content="summary" name="twitter:card"/>
#       <meta content="" name="twitter:title"/>
#       <meta content="https://www.naver.com/" name="twitter:url"/>
#       <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" name="twitter:image"/>
#       <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="twitter:description">
#        <meta content="uru5NJKa1Bfr5nv5AdQ26Qat7UrPU_02l-PIZRLzI-g" name="google-site-verification">
#         <link href="/favicon.ico?1" rel="shortcut icon" type="image/x-icon"/>
#         <link href="https://s.pstatic.net/static/www/nFavicon96.png" rel="apple-touch-icon-precomposed">
#          <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png" rel="apple-touch-icon" sizes="114x114"/>
#          <link href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png" rel="apple-touch-icon"/>
#          <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_251001.css" rel="stylesheet"/>
#          <link href="https://www.naver.com/" rel="canonical"/>
#          <link href="https://m.naver.com/" media="only screen and (max-width: 767px)" rel="alternate"/>
#          <script>
#           window.gladsdk=window.gladsdk||{},window.gladsdk.cmd=window.gladsdk.cmd||[],window.ndpsdk=window.ndpsdk||{},window.ndpsdk.cmd=window.ndpsdk.cmd||[],window.ndpsdk.polyfill=window.ndpsdk.polyfill||{cmd:[]};var g_ssc="navertop.v5";window.nsc=g_ssc,window.nmain=window.nmain||{},window.nmain.jsOrigin="www"
#          </script>
#          <script>
#           window.ntm=window.ntm||[]
#          </script>
#          <script async="" src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js">
#          </script>

# %%
# 문자열 HTML 파싱 및 BeautifulSoup 객체 확인


# 1. "HTML 문자열 정의" (HTML String Definition)
html_str = "<!DOCTYPE html><html><div>hello</div></html>"


# 2. "BeautifulSoup 객체 생성 및 타입 확인" (BeautifulSoup Object Creation and Type Check)

# bs4.BeautifulSoup() 생성자를 사용하여 파싱 객체를 만듭니다.
# 첫 번째 인수인 'html_str'은 분석할 HTML 문자열입니다.
# 두 번째 인수인 'html.parser'는 Python 표준 라이브러리에 내장된 "HTML 파서"를 사용하도록 지정합니다.
# 파싱된 구조화된 객체는 'bs_obj' 변수에 저장됩니다.
bs_obj = bs4.BeautifulSoup(html_str, "html.parser")

# 'bs_obj' 변수의 "타입"을 출력합니다.
# 출력 결과는 "<class 'bs4.BeautifulSoup'>"이며, 이는 HTML 문자열이 
# 성공적으로 "BeautifulSoup 객체"로 변환되어 데이터 추출 준비가 완료되었음을 나타냅니다.
print(type(bs_obj))

# 생성된 'bs_obj' 객체의 내용 전체를 출력합니다.
# BeautifulSoup이 <html> 태그를 인식하고 내부 구조를 포함하여 출력하는 것을 볼 수 있습니다.
print(bs_obj)
# Out:
# <class 'bs4.BeautifulSoup'>
# <!DOCTYPE html>
# <html><div>hello</div></html>

# %%
# 3. "데이터 검색 및 텍스트 추출" (Data Search and Text Extraction)


# 'bs_obj' 객체의 ".find('div')" 메서드를 호출합니다.
# 이는 BeautifulSoup 트리 구조에서 "첫 번째로 발견되는 'div' 태그 요소"를 찾아 반환합니다.
# 출력 결과는 <div>hello</div> 형태의 태그 객체입니다.
print(bs_obj.find('div'))

# ".find('div')"로 찾은 'div' 태그 객체 뒤에 ".text" 속성을 붙입니다.
# ".text" 속성은 해당 태그 객체가 포함하고 있는 "순수한 텍스트 내용"만을 추출합니다.
# 출력 결과는 'hello' 문자열입니다.
print(bs_obj.find('div').text)
# Out:
# <div>hello</div>
# hello

# %%
# --- BeautifulSoup을 이용한 데이터 목록(List) 추출 ---


# 1. "HTML 문자열 정의 및 객체 생성" (HTML Definition and Object Creation)

# 여러 개의 목록 항목(<li>)을 포함하는 HTML 문자열을 정의합니다.
html_str = """
<!DOCTYPE html>
<html>
    <body>
        <ul>
            <li>hello</li>
            <li>bye</li>
            <li>welcome</li>
        </ul>
    </body>
</html>
"""

# BeautifulSoup 객체를 생성합니다.
# 'html_str' 문자열을 'html.parser'를 사용하여 분석하고, 그 결과를 'bs_obj'에 저장합니다.
bs_obj = bs4.BeautifulSoup(html_str,'html.parser')
bs_obj
# Out:
# <!DOCTYPE html>
#
# <html>
# <body>
# <ul>
# <li>hello</li>
# <li>bye</li>
# <li>welcome</li>
# </ul>
# </body>
# </html>

# %%
# 2. "최상위 목록 태그 검색" (Finding the Top-Level List Tag)


# "bs_obj.find('ul')" 메서드를 사용하여 문서에서 "첫 번째로 발견되는 'ul' 태그 요소" 전체를 찾습니다.
# 'ul_t' 변수는 <ul>...</ul> 전체를 포함하는 BeautifulSoup 태그 객체가 됩니다.
ul_t = bs_obj.find('ul')
# 찾은 'ul' 태그 객체의 전체 내용을 출력합니다.
print(ul_t)

# 'ul_t' 객체 내에서 ".find('li')" 메서드를 사용하여 "첫 번째로 발견되는 'li' 태그 요소"를 찾습니다.
# 출력 없이 실행되었지만, 결과는 '<li>hello</li>' 객체가 됩니다.
ul_t.find('li')
# Out:
# <ul>
# <li>hello</li>
# <li>bye</li>
# <li>welcome</li>
# </ul>
# <li>hello</li>

# %%
# 3. "모든 목록 항목 추출" (Extracting All List Items)


# 'ul_t' 객체 내에서 ".findAll('li')" 메서드를 사용하여 "모든 'li' 태그 요소"를 검색합니다.
# 찾은 모든 요소는 리스트 형태로 'uls' 변수에 저장됩니다.
uls = ul_t.findAll('li')
# 'uls' 리스트의 내용을 출력합니다. (각 <li> 태그 객체들이 리스트의 요소로 포함됨)
print(uls)


# 'uls' 리스트의 "세 번째 요소" (인덱스 2)의 "타입"을 출력합니다.
# 출력 결과는 "<class 'bs4.element.Tag'>"로, 리스트 요소가 태그 객체임을 보여줍니다.
print(type(uls[2]))
# 세 번째 'li' 태그 객체에서 ".text" 속성을 사용하여 "순수한 텍스트"('welcome')만 추출하여 출력합니다.
print(uls[2].text)


# 'uls' 리스트의 각 'li' 태그 객체에 대해 반복문(for loop)을 실행합니다.
for li in uls :
    # 각 'li' 객체에서 ".text"를 사용하여 텍스트 내용을 추출하고 출력합니다.
    # 이 과정으로 'hello', 'bye', 'welcome'이 각각 한 줄씩 출력됩니다.
    print(li.text)
# Out:
# [<li>hello</li>, <li>bye</li>, <li>welcome</li>]
# <class 'bs4.element.Tag'>
# welcome
# hello
# bye
# welcome

# %%
# 4. "전체 텍스트 추출 및 정제" (Full Text Extraction and Cleaning) 


# 'ul_t' 객체 전체에서 ".text" 속성을 사용하여 "모든 하위 태그의 텍스트"를 한 번에 추출합니다.
# 이 과정에서 HTML의 공백(개행 문자, 탭 등)도 텍스트에 포함되어 추출됩니다.
print(ul_t.text)

# 'ul_t.text'의 결과 문자열을 Python의 ".split('\n')" 메서드를 사용하여 "개행 문자('\n') 기준"으로 나눕니다.
# 결과는 불필요한 공백 문자열이 포함된 리스트가 됩니다.
print(ul_t.text.split('\n'))
# Out:
# hello
# bye
# welcome
#
# ['', 'hello', 'bye', 'welcome', '']

# %%
# --- BeautifulSoup 클래스 및 복합 조건 검색 ---


# 1. "HTML 문자열 정의 및 객체 생성" (HTML Definition and Object Creation)


# 'greet'과 'reply' 두 개의 다른 클래스를 가진 <ul> 목록을 포함하는 HTML 문자열을 정의합니다.
html_str = """
<!DOCTYPE html>
<html>
    <body>
        <ul class="greet">
            <li>hello</li>
            <li>bye</li>
            <li>welcome</li>
        </ul>
        <ul class="reply">
            <li>ok</li>
            <li>no</li>
            <li>sure</li>
        </ul>
    </body>
</html>
"""
# BeautifulSoup 객체를 생성합니다. 'html_str'을 'html.parser'로 분석하고 'bs_obj'에 저장합니다.
bs_obj = bs4.BeautifulSoup(html_str,'html.parser')
bs_obj
# Out:
# <!DOCTYPE html>
#
# <html>
# <body>
# <ul class="greet">
# <li>hello</li>
# <li>bye</li>
# <li>welcome</li>
# </ul>
# <ul class="reply">
# <li>ok</li>
# <li>no</li>
# <li>sure</li>
# </ul>
# </body>
# </html>

# %%
# 2. "단일 요소 검색 (find)" (Single Element Search)


# 문서에서 "첫 번째로 발견되는" 'ul' 태그 요소를 찾습니다.
# 결과는 클래스가 'greet'인 <ul> 요소입니다.
bs_obj.find('ul')
# Out:
# <ul class="greet">
# <li>hello</li>
# <li>bye</li>
# <li>welcome</li>
# </ul>

# %%
# 'ul' 태그 중에서, 속성 딕셔너리 {'class':'greet'}와 "일치하는" 첫 번째 요소를 찾습니다.
# 이는 'greet' 클래스를 가진 <ul> 요소를 정확하게 지정하여 찾습니다.
bs_obj.find('ul',{'class':'greet'})
# Out:
# <ul class="greet">
# <li>hello</li>
# <li>bye</li>
# <li>welcome</li>
# </ul>

# %%
# 3. "모든 요소 검색 (findAll)" (Multiple Element Search)


# 문서에서 "모든" 'ul' 태그 요소를 리스트로 찾은 후, 그 리스트의 "두 번째 요소" (인덱스 1)를 선택합니다.
# 결과는 클래스가 'reply'인 <ul> 요소입니다.
bs_obj.findAll('ul')[1]
# Out:
# <ul class="reply">
# <li>ok</li>
# <li>no</li>
# <li>sure</li>
# </ul>

# %%
# 'ul' 태그 중에서, 클래스가 'reply'인 "첫 번째" 요소를 찾습니다.
# 'reply' 클래스를 가진 <ul> 요소가 하나밖에 없으므로, 이를 정확히 반환합니다.
bs_obj.find('ul',{'class':'reply'})
# Out:
# <ul class="reply">
# <li>ok</li>
# <li>no</li>
# <li>sure</li>
# </ul>

# %%
# 'ul' 태그 중에서, 클래스가 'reply'인 "모든" 요소를 찾아 리스트로 반환합니다.
# 이 경우, 요소가 하나이므로, 그 하나를 담은 리스트가 반환됩니다.
bs_obj.findAll('ul',{'class':'reply'})
# Out:
# [<ul class="reply">
#  <li>ok</li>
#  <li>no</li>
#  <li>sure</li>
#  </ul>]

# %%
# 4. "일반 태그 검색 및 별칭 사용" (General Tag Search and Aliases)


# 문서 전체에서 "모든" 'li' 태그 요소를 찾아 리스트로 반환합니다. (hello, bye, welcome, ok, no, sure 모두 포함)
bs_obj.find_all('li')
# Out:
# [<li>hello</li>,
#  <li>bye</li>,
#  <li>welcome</li>,
#  <li>ok</li>,
#  <li>no</li>,
#  <li>sure</li>]

# %%
# 'findAll'은 'find_all'의 "별칭(alias)"입니다. 기능은 완전히 동일하며, 문서의 모든 'li' 태그를 반환합니다.
bs_obj.findAll('li')
# Out:
# [<li>hello</li>,
#  <li>bye</li>,
#  <li>welcome</li>,
#  <li>ok</li>,
#  <li>no</li>,
#  <li>sure</li>]

# %%
# 문서 전체에서 "모든" 'ul' 태그 요소를 찾아 리스트로 반환합니다. ('greet'과 'reply' 두 개 모두 포함)
bs_obj.find_all('ul')
# Out:
# [<ul class="greet">
#  <li>hello</li>
#  <li>bye</li>
#  <li>welcome</li>
#  </ul>,
#  <ul class="reply">
#  <li>ok</li>
#  <li>no</li>
#  <li>sure</li>
#  </ul>]

# %%
# 5. "계층적 검색 (Method Chaining)" (Hierarchical Search)


# 1단계: "첫 번째 'ul'" 태그('greet' 클래스)를 찾습니다.
# 2단계: 그 찾은 'ul' 태그 내부에서 "모든 'li'" 태그를 찾습니다. (hello, bye, welcome)
# 이는 특정 부모 태그 내부의 자식 요소들을 추출하는 "대표적인 방식"입니다.
bs_obj.find('ul').find_all('li')
# Out:
# [<li>hello</li>, <li>bye</li>, <li>welcome</li>]

# %%
# 1단계: "모든 'ul'" 태그를 리스트로 찾고, 그 리스트의 "첫 번째 요소" (인덱스 0, 'greet' 클래스)를 선택합니다.
# 2단계: 그 'ul' 태그 내부에서 "모든 'li'" 태그를 찾습니다. (hello, bye, welcome)
bs_obj.find_all('ul')[0].find_all('li')
# Out:
# [<li>hello</li>, <li>bye</li>, <li>welcome</li>]

# %%
# 1단계: 클래스가 'greet'인 'ul' 태그를 "정확하게 지정"하여 찾습니다.
# 2단계: 그 'ul' 태그 내부에서 "모든 'li'" 태그를 찾습니다. (hello, bye, welcome)
bs_obj.find('ul',{'class':'greet'}).find_all('li')
# Out:
# [<li>hello</li>, <li>bye</li>, <li>welcome</li>]

# %%
# 1단계: 클래스가 'greet'인 'ul' 태그를 모두 찾아 리스트로 얻고, "첫 번째 요소"를 선택합니다.
# 2단계: 그 'ul' 태그 내부에서 "모든 'li'" 태그를 찾습니다. (hello, bye, welcome)
bs_obj.find_all('ul',{'class':'greet'})[0].find_all('li')


# "핵심 요약"
# 가장 중요한 패턴은 **find('parent_tag', {...})**를 사용하여 원하는 부모 요소를 정확히 찾아낸 후, 
# **.find_all('child_tag')**를 체인 형태로 연결하여 그 하위의 모든 데이터를 효율적으로 추출하는 "계층적 검색" 방식입니다.
# Out:
# [<li>hello</li>, <li>bye</li>, <li>welcome</li>]

# %%
# --- BeautifulSoup ID 속성 기반 검색 ---


# 1. "HTML 문자열 정의 및 객체 생성" (HTML Definition and Object Creation)

# 'id' 속성(title, crawling, parsing)을 가진 여러 태그를 포함하는 HTML 문자열을 정의합니다.
html_str = """
<!DOCTYPE html>
<html>
    <body>
        <h1 id='title'>Hello Python</h1>
        <p id="crawling">웹 크롤링</p>
        <p id="parsing">파싱</p>
    </body>
</html>
"""

# BeautifulSoup 객체를 생성합니다.
# 'html_str' 문자열을 'html.parser'를 사용하여 분석하고, 그 결과를 'bs_obj'에 저장합니다.
bs_obj = bs4.BeautifulSoup(html_str, 'html.parser')

# %%
# 2. "ID 속성을 사용한 단일 요소 검색" (Single Element Search using ID)


# 1단계: 검색할 태그 이름('h1')을 지정합니다.
# 2단계: "딕셔너리 형태"의 속성 조건 {'id':'title'}을 지정하여 해당 조건을 만족하는 요소를 찾습니다.
# 결과는 "id가 'title'인 첫 번째 'h1' 태그" (<h1>Hello Python</h1>)가 됩니다.
bs_obj.find('h1',{'id':'title'})
# Out:
# <h1 id="title">Hello Python</h1>

# %%
# 1단계: 검색할 태그 이름('p')을 지정합니다.
# 2단계: 속성 조건 {'id':'parsing'}을 지정하여 해당 조건을 만족하는 요소를 찾습니다.
# 결과는 "id가 'parsing'인 첫 번째 'p' 태그" (<p id="parsing">파싱</p>)가 됩니다.
bs_obj.find('p',{'id':'parsing'})


# "핵심 요약"
# HTML에서 **id**는 일반적으로 문서 내에서 **"유일성"**을 보장하는 식별자입니다. 
# 따라서 find(tag, {'id': 'id_value'}) 형태는 특정 태그 중에서 "가장 정확하고 빠르게" 
# 원하는 하나의 요소를 찾아내는 데 매우 효과적인 방법입니다.
# Out:
# <p id="parsing">파싱</p>

# %%
# --- BeautifulSoup 형제 요소 탐색 ---


# 1. "HTML 문자열 정의 및 객체 생성" (HTML Definition and Object Creation) 

# 여러 개의 연속된 <p> 태그를 포함하는 HTML 문자열을 정의합니다.
html_str = """
<!DOCTYPE html>
<html>
    <body>
        <h1>파이썬 프로그래밍</h1>
        <p>웹 페이지 분석</p><p>크롤링</p><p>파싱</p>        
    </body>
</html>
"""

# BeautifulSoup 객체를 생성합니다.
# 'html_str' 문자열을 'html.parser'를 사용하여 분석하고, 그 결과를 'bs_obj'에 저장합니다.
bs_obj = bs4.BeautifulSoup(html_str, 'html.parser')

# %%
# 2. "태그 검색" (Tag Search)


# 문서에서 "첫 번째로 발견되는" '<p>' 태그 요소를 찾습니다.
# 결과는 <p>웹 페이지 분석</p> 태그 객체가 됩니다.
bs_obj.find('p')
# Out:
# <p>웹 페이지 분석</p>

# %%
# 문서 전체에서 "모든" '<p>' 태그 요소를 찾아 리스트 형태로 반환합니다.
# 결과는 [<p>웹 페이지 분석</p>, <p>크롤링</p>, <p>파싱</p>] 리스트가 됩니다.
bs_obj.find_all('p')
# Out:
# [<p>웹 페이지 분석</p>, <p>크롤링</p>, <p>파싱</p>]

# %%
# 3. "형제 요소 탐색 (next_sibling)" (Sibling Element Navigation)


# "첫 번째 '<p>' 태그" (<p>웹 페이지 분석</p>)를 찾아서 'p1' 변수에 저장합니다.
p1 = bs_obj.find('p')


# 'p1' (첫 번째 <p> 태그)의 "바로 다음 형제 요소"를 출력합니다.
# HTML 소스에서 첫 번째 <p> 바로 뒤에는 두 번째 <p> 태그가 붙어 있습니다.
# 따라서, "다음 형제 요소"는 <p>크롤링</p> 태그 객체가 됩니다.
print(p1.next_sibling)

# 1단계: 'p1'의 "다음 형제" (<p>크롤링</p>)를 찾습니다.
# 2단계: 그 "다음 형제" (<p>크롤링</p>)의 "또 다음 형제"를 찾습니다.
# 결과는 세 번째 <p> 태그인 <p>파싱</p> 태그 객체가 됩니다.
# 이는 동일한 부모('body') 아래에 있는 요소를 "순차적으로 이동"하며 탐색하는 방법입니다.
print(p1.next_sibling.next_sibling)



# "핵심 요약"

# **next_sibling**은 BeautifulSoup에서 **"DOM 트리 구조상 같은 부모 아래에 있는 다음 요소"**로 이동할 때 사용됩니다. 
# 만약 HTML 소스에서 태그 사이에 공백이나 개행 문자(줄 바꿈)가 있다면, 
# **next_sibling**은 태그 객체가 아닌 "NavigableString(문자열)" 객체를 반환할 수 있으므로 주의해야 합니다. 
# 이 예시에서는 <p> 태그들이 공백 없이 붙어있어 바로 다음 <p> 태그를 반환했습니다.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       1 # 3. "형제 요소 탐색 (next_sibling)" (Sibling Element Navigation)
#       2
#       3
#       4 # "첫 번째 '<p>' 태그" (<p>웹 페이지 분석</p>)를 찾아서 'p1' 변수에 저장합니다.
# ----> 5 p1 = bs_obj.find('p')
#       7 # print(p1.next_sibling)
#       8 # 'p1' (첫 번째 <p> 태그)의 "바로 다음 형제 요소"를 출력합니다.
#       9 # HTML 소스에서 첫 번째 <p> 바로 뒤에는 두 번째 <p> 태그가 붙어 있습니다.
#      10 # 따라서, "다음 형제 요소"는 <p>크롤링</p> 태그 객체가 됩니다.
#      11 print(p1.next_sibling)
#
# NameError: name 'bs_obj' is not defined

# %%
# --- BeautifulSoup을 이용한 하이퍼링크 데이터 추출 및 DataFrame 생성 ---


# 1. "HTML 정의 및 BeautifulSoup 객체 생성" (HTML Definition and Parsing)

# 클래스가 'ko'와 'sns'인 두 개의 <ul> 목록에 여러 개의 하이퍼링크(<a> 태그)를 포함하는 HTML 문자열을 정의합니다.
html_str = """
<!DOCTYPE html>
<html>
    <body>
        <ul class="ko">
            <li><a href="https://www.naver.com/">네이버</a></li>
            <li><a href="https://www.daum.net/">다음</a></li>
        </ul>
        <ul class="sns">
            <li><a href="https://www.goole.com/">구글</a></li>
            <li><a href="https://www.facebook.net/">페이스북</a></li>
        </ul>
    </body>
</html>
"""

# BeautifulSoup 객체를 생성합니다. 'html_str'을 'html.parser'로 분석하고 'bs_obj'에 저장합니다.
bs_obj = bs4.BeautifulSoup(html_str,'html.parser')
bs_obj
# Out:
# <!DOCTYPE html>
#
# <html>
# <body>
# <ul class="ko">
# <li><a href="https://www.naver.com/">네이버</a></li>
# <li><a href="https://www.daum.net/">다음</a></li>
# </ul>
# <ul class="sns">
# <li><a href="https://www.goole.com/">구글</a></li>
# <li><a href="https://www.facebook.net/">페이스북</a></li>
# </ul>
# </body>
# </html>

# %%
# 2. "태그 검색 및 기본 속성 추출" (Tag Search and Basic Attribute Extraction)


# 문서 전체에서 "모든 'li' 태그 요소"를 찾아 리스트로 반환합니다. (총 4개)
bs_obj.find_all('li')
# Out:
# [<li><a href="https://www.naver.com/">네이버</a></li>,
#  <li><a href="https://www.daum.net/">다음</a></li>,
#  <li><a href="https://www.goole.com/">구글</a></li>,
#  <li><a href="https://www.facebook.net/">페이스북</a></li>]

# %%
# 문서 전체에서 "모든 'a' 태그 요소" (하이퍼링크)를 찾아 리스트로 반환합니다. (총 4개)
bs_obj.find_all('a')
# Out:
# [<a href="https://www.naver.com/">네이버</a>,
#  <a href="https://www.daum.net/">다음</a>,
#  <a href="https://www.goole.com/">구글</a>,
#  <a href="https://www.facebook.net/">페이스북</a>]

# %%
# 1단계: 모든 <a> 태그를 찾습니다.
# 2단계: 리스트의 "첫 번째 요소" (인덱스 0, 네이버 링크)를 선택합니다.
# 3단계: 태그 객체에 "딕셔너리처럼 접근"하여 'href' 속성 값(URL 문자열)을 추출합니다.
bs_obj.find_all('a')[0]['href']
# Out:
# 'https://www.naver.com/'

# %%
# 1단계: 첫 번째 <a> 태그 요소를 선택합니다.
# 2단계: ".text" 속성을 사용하여 태그 안의 "순수한 텍스트"('네이버')를 추출합니다.
bs_obj.find_all('a')[0].text
# Out:
# '네이버'

# %%
# 3. "반복문을 이용한 URL 추출" (Extracting URLs via Loop)


hrefs=[] # 추출한 URL을 저장할 빈 리스트를 초기화합니다.
# bs_obj.find_all('a')를 사용하여 찾은 모든 <a> 태그 요소에 대해 반복합니다.
for a in bs_obj.find_all('a') :
    # 현재 <a> 태그의 'href' 속성 값을 추출하여 출력합니다.
    print(a['href'])
    # 추출한 URL을 'hrefs' 리스트에 추가합니다.
    hrefs.append(a['href'])
# Out:
# https://www.naver.com/
# https://www.daum.net/
# https://www.goole.com/
# https://www.facebook.net/

# %%
# 이전 리스트를 재사용하기 위해 초기화하고, 이름 저장을 위한 'name' 리스트도 초기화합니다.
hrefs=[]
name = []
# 모든 <a> 태그에 대해 다시 반복합니다.
for a in bs_obj.find_all('a') :
    # 현재 <a> 태그의 텍스트(사이트 이름)를 'name' 리스트에 추가합니다.
    name.append(a.text)
    # 현재 <a> 태그의 'href' 속성(URL)을 'hrefs' 리스트에 추가합니다.
    hrefs.append(a['href'])


# 최종적으로 추출된 두 리스트 ('hrefs'와 'name')의 내용을 출력합니다.
print(f"hrefs : {hrefs}, name : {name}")
# Out:
# hrefs : ['https://www.naver.com/', 'https://www.daum.net/', 'https://www.goole.com/', 'https://www.facebook.net/'], name : ['네이버', '다음', '구글', '페이스북']

# %%
# pd.DataFrame() 생성자를 사용하여 최종 데이터 프레임을 생성합니다.
# 딕셔너리를 인수로 전달하며, 딕셔너리의 "키"는 DataFrame의 "컬럼 이름"이 되고,
# "값"은 추출된 리스트('name', 'hrefs')가 됩니다.
pd.DataFrame(
    {
        'site명' : name, 
        'siteURL' : hrefs
    }
)
# 결과는 사이트 이름과 URL이 깔끔하게 정리된 표 형태의 데이터 프레임입니다.


# "핵심 요약"
# 이 코드는 웹 스크래핑의 실용적인 최종 단계를 보여줍니다. 
# **find_all('a')**를 통해 반복되는 데이터를 추출하고, 
# 반복문을 사용하여 **"텍스트 내용 (.text)"**과 **"속성 값 (['속성명'])"**을 동시에 리스트에 저장한 후, 
# Pandas를 이용해 이 데이터를 구조화된 테이블 형태로 변환합니다.
# Out:
#   site명                    siteURL
# 0   네이버     https://www.naver.com/
# 1    다음      https://www.daum.net/
# 2    구글     https://www.goole.com/
# 3  페이스북  https://www.facebook.net/

# %%
# --- BeautifulSoup CSS 선택자(Selector)를 이용한 데이터 추출 ---


# 1. "HTML 정의 및 BeautifulSoup 객체 생성" (HTML Definition and Object Creation)

# 여러 <div>, <ul>, <table>, <a>, <img> 태그와 ID 및 클래스 속성을 포함하는 복잡한 HTML 구조입니다.
html_str = """
<!DOCTYPE html>
<html>
    <body>
        <div id="wrap">
            <div id="mainMenuBox">                  
                <ul> 
                    <li><a href="#">패션잡화</a></li>    
                    <li><a href="#">주방용품</a></li>                      
                    <li><a href="#">생활건강</a></li>
                    <li><a href="#">DIY가구</a></li>
                </ul>
            </div>
            <div>
                <table>
                    <tr>
                        <td><img src="shoes1.jpg"></td>
                        <td><img src="shoes2.jpg"></td>
                        <td><img src="shoes3.jpg"></td>
                    </tr>
                    <tr id="prdName">
                        <td>솔로이스트<br>걸리쉬 리본단화</td>
                        <td>맥컬린<br>그레이가보시스트랩 펌프스</td>
                        <td>맥컬린<br>섹슈얼인사이드펌프스</td>
                    </tr>
                    <tr id="price">
                        <td>100,000원</td>
                        <td>200,000원</td>
                        <td>120,000원</td>
                    </tr>
                </table>
            </div>
            <div id="out_box">
                <div class="box">
                    <h4>공지사항</h4>
                    <hr>
                    <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a><br>
                    <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a><br>
                    <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>                      
                </div>
                <div class="box">
                    <h4>커뮤니티</h4>
                    <hr>
                    <a href="#">[레시피] : 살 안찌는 야식 만들기</a><br>
                    <a href="#">[가구] : 헌집 새집 베스트 가구</a><br>
                    <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a><br>
                </div>
            </div>          
        </div>
    </body>
</html>
"""

# BeautifulSoup 객체를 생성합니다. HTML 문자열을 'html.parser'로 분석하고 'bs_obj'에 저장합니다.
bs_obj = bs4.BeautifulSoup(html_str,'html.parser')
bs_obj
# Out:
# <!DOCTYPE html>
#
# <html>
# <body>
# <div id="wrap">
# <div id="mainMenuBox">
# <ul>
# <li><a href="#">패션잡화</a></li>
# <li><a href="#">주방용품</a></li>
# <li><a href="#">생활건강</a></li>
# <li><a href="#">DIY가구</a></li>
# </ul>
# </div>
# <div>
# <table>
# <tr>
# <td><img src="shoes1.jpg"/></td>
# <td><img src="shoes2.jpg"/></td>
# <td><img src="shoes3.jpg"/></td>
# </tr>
# <tr id="prdName">
# <td>솔로이스트<br/>걸리쉬 리본단화</td>
# <td>맥컬린<br/>그레이가보시스트랩 펌프스</td>
# <td>맥컬린<br/>섹슈얼인사이드펌프스</td>
# </tr>
# <tr id="price">
# <td>100,000원</td>
# <td>200,000원</td>
# <td>120,000원</td>
# </tr>
# </table>
# </div>
# <div id="out_box">
# <div class="box">
# <h4>공지사항</h4>
# <hr/>
# <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a><br/>
# <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a><br/>
# <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>
# </div>
# <div class="box">
# <h4>커뮤니티</h4>
# <hr/>
# <a href="#">[레시피] : 살 안찌는 야식 만들기</a><br/>
# <a href="#">[가구] : 헌집 새집 베스트 가구</a><br/>
# <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a><br/>
# </div>
# </div>
# </div>
# </body>
# </html>

# %%
# 2. "기본 검색 및 선택자 활용" (Basic Search and Selector Usage)


# find_all() 메서드를 사용하여 문서 전체의 "모든 <a> 태그"를 찾아 리스트로 반환합니다. (총 10개)
bs_obj.findAll("a")
# Out:
# [<a href="#">패션잡화</a>,
#  <a href="#">주방용품</a>,
#  <a href="#">생활건강</a>,
#  <a href="#">DIY가구</a>,
#  <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a>,
#  <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a>,
#  <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>,
#  <a href="#">[레시피] : 살 안찌는 야식 만들기</a>,
#  <a href="#">[가구] : 헌집 새집 베스트 가구</a>,
#  <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a>]

# %%
# select() 메서드를 사용하여 CSS 선택자 'a'와 일치하는 "모든 <a> 태그"를 찾아 리스트로 반환합니다. (findAll과 동일 결과)
bs_obj.select('a')
# Out:
# [<a href="#">패션잡화</a>,
#  <a href="#">주방용품</a>,
#  <a href="#">생활건강</a>,
#  <a href="#">DIY가구</a>,
#  <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a>,
#  <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a>,
#  <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>,
#  <a href="#">[레시피] : 살 안찌는 야식 만들기</a>,
#  <a href="#">[가구] : 헌집 새집 베스트 가구</a>,
#  <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a>]

# %%
# select() 메서드를 사용하여 문서 전체의 "모든 <div> 태그"를 찾아 리스트로 반환합니다. (총 5개: wrap, mainMenuBox, unnamed div, out_box, 2개의 box 클래스)
bs_obj.select('div')
# Out:
# [<div id="wrap">
#  <div id="mainMenuBox">
#  <ul>
#  <li><a href="#">패션잡화</a></li>
#  <li><a href="#">주방용품</a></li>
#  <li><a href="#">생활건강</a></li>
#  <li><a href="#">DIY가구</a></li>
#  </ul>
#  </div>
#  <div>
#  <table>
#  <tr>
#  <td><img src="shoes1.jpg"/></td>
#  <td><img src="shoes2.jpg"/></td>
#  <td><img src="shoes3.jpg"/></td>
#  </tr>
#  <tr id="prdName">
#  <td>솔로이스트<br/>걸리쉬 리본단화</td>
#  <td>맥컬린<br/>그레이가보시스트랩 펌프스</td>
#  <td>맥컬린<br/>섹슈얼인사이드펌프스</td>
#  </tr>
#  <tr id="price">
#  <td>100,000원</td>
#  <td>200,000원</td>
#  <td>120,000원</td>
#  </tr>
#  </table>
#  </div>
#  <div id="out_box">
#  <div class="box">
#  <h4>공지사항</h4>
#  <hr/>
#  <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a><br/>
#  <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a><br/>
#  <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>
#  </div>
#  <div class="box">
#  <h4>커뮤니티</h4>
#  <hr/>
#  <a href="#">[레시피] : 살 안찌는 야식 만들기</a><br/>
#  <a href="#">[가구] : 헌집 새집 베스트 가구</a><br/>
#  <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a><br/>
#  </div>
#  </div>
#  </div>,
#  <div id="mainMenuBox">
#  <ul>
#  <li><a href="#">패션잡화</a></li>
#  <li><a href="#">주방용품</a></li>
#  <li><a href="#">생활건강</a></li>
#  <li><a href="#">DIY가구</a></li>
#  </ul>
#  </div>,
#  <div>
#  <table>
#  <tr>
#  <td><img src="shoes1.jpg"/></td>
#  <td><img src="shoes2.jpg"/></td>
#  <td><img src="shoes3.jpg"/></td>
#  </tr>
#  <tr id="prdName">
#  <td>솔로이스트<br/>걸리쉬 리본단화</td>
#  <td>맥컬린<br/>그레이가보시스트랩 펌프스</td>
#  <td>맥컬린<br/>섹슈얼인사이드펌프스</td>
#  </tr>
#  <tr id="price">
#  <td>100,000원</td>
#  <td>200,000원</td>
#  <td>120,000원</td>
#  </tr>
#  </table>
#  </div>,
#  <div id="out_box">
#  <div class="box">
#  <h4>공지사항</h4>
#  <hr/>
#  <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a><br/>
#  <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a><br/>
#  <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>
#  </div>
#  <div class="box">
#  <h4>커뮤니티</h4>
#  <hr/>
#  <a href="#">[레시피] : 살 안찌는 야식 만들기</a><br/>
#  <a href="#">[가구] : 헌집 새집 베스트 가구</a><br/>
#  <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a><br/>
#  </div>
#  </div>,
#  <div class="box">
#  <h4>공지사항</h4>
#  <hr/>
#  <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a><br/>
#  <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a><br/>
#  <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>
#  </div>,
#  <div class="box">
#  <h4>커뮤니티</h4>
#  <hr/>
#  <a href="#">[레시피] : 살 안찌는 야식 만들기</a><br/>
#  <a href="#">[가구] : 헌집 새집 베스트 가구</a><br/>
#  <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a><br/>
#  </div>]

# %%
# 3. "ID 및 계층 선택자" (ID and Hierarchical Selectors)


# 'div' 태그의 후손(descendant) 중에서 "ID가 mainMenuBox인 요소"를 찾습니다. (공백은 후손 선택자)
bs_obj.select('div #mainMenuBox')
# Out:
# [<div id="mainMenuBox">
#  <ul>
#  <li><a href="#">패션잡화</a></li>
#  <li><a href="#">주방용품</a></li>
#  <li><a href="#">생활건강</a></li>
#  <li><a href="#">DIY가구</a></li>
#  </ul>
#  </div>]

# %%
# "ID가 mainMenuBox인 요소"를 바로 찾습니다. (ID 선택자 #을 사용)
bs_obj.select('#mainMenuBox')
# Out:
# [<div id="mainMenuBox">
#  <ul>
#  <li><a href="#">패션잡화</a></li>
#  <li><a href="#">주방용품</a></li>
#  <li><a href="#">생활건강</a></li>
#  <li><a href="#">DIY가구</a></li>
#  </ul>
#  </div>]

# %%
# ID가 mainMenuBox인 요소의 "후손" 중에서 "모든 <ul> 태그"를 찾습니다.
bs_obj.select('#mainMenuBox ul')
# Out:
# [<ul>
#  <li><a href="#">패션잡화</a></li>
#  <li><a href="#">주방용품</a></li>
#  <li><a href="#">생활건강</a></li>
#  <li><a href="#">DIY가구</a></li>
#  </ul>]

# %%
# ID가 mainMenuBox인 요소의 "직계 자식" 중에서 "모든 <ul> 태그"를 찾습니다. (>는 자식 선택자)
bs_obj.select('#mainMenuBox > ul')
# Out:
# [<ul>
#  <li><a href="#">패션잡화</a></li>
#  <li><a href="#">주방용품</a></li>
#  <li><a href="#">생활건강</a></li>
#  <li><a href="#">DIY가구</a></li>
#  </ul>]

# %%
# ID가 mainMenuBox인 요소의 후손 중에서 "모든 <li> 태그"를 찾아 출력합니다. (4개 항목)
bs_obj.select('#mainMenuBox li')
# Out:
# [<li><a href="#">패션잡화</a></li>,
#  <li><a href="#">주방용품</a></li>,
#  <li><a href="#">생활건강</a></li>,
#  <li><a href="#">DIY가구</a></li>]

# %%
# ID가 mainMenuBox인 요소의 "직계 자식" 중에서 'li' 태그를 찾습니다.
# mainMenuBox의 직계 자식은 <ul>이므로 <li>는 찾지 못하여 "빈 리스트"가 반환됩니다.
bs_obj.select('#mainMenuBox > li')
# Out:
# []

# %%
# ID가 wrap인 요소의 "직계 자식" 중에서 "모든 <div> 태그"를 찾습니다. (총 3개의 <div>)
bs_obj.select("#wrap > div")
# Out:
# [<div id="mainMenuBox">
#  <ul>
#  <li><a href="#">패션잡화</a></li>
#  <li><a href="#">주방용품</a></li>
#  <li><a href="#">생활건강</a></li>
#  <li><a href="#">DIY가구</a></li>
#  </ul>
#  </div>,
#  <div>
#  <table>
#  <tr>
#  <td><img src="shoes1.jpg"/></td>
#  <td><img src="shoes2.jpg"/></td>
#  <td><img src="shoes3.jpg"/></td>
#  </tr>
#  <tr id="prdName">
#  <td>솔로이스트<br/>걸리쉬 리본단화</td>
#  <td>맥컬린<br/>그레이가보시스트랩 펌프스</td>
#  <td>맥컬린<br/>섹슈얼인사이드펌프스</td>
#  </tr>
#  <tr id="price">
#  <td>100,000원</td>
#  <td>200,000원</td>
#  <td>120,000원</td>
#  </tr>
#  </table>
#  </div>,
#  <div id="out_box">
#  <div class="box">
#  <h4>공지사항</h4>
#  <hr/>
#  <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a><br/>
#  <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a><br/>
#  <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>
#  </div>
#  <div class="box">
#  <h4>커뮤니티</h4>
#  <hr/>
#  <a href="#">[레시피] : 살 안찌는 야식 만들기</a><br/>
#  <a href="#">[가구] : 헌집 새집 베스트 가구</a><br/>
#  <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a><br/>
#  </div>
#  </div>]

# %%
# 직계 자식인 <div> 요소의 개수를 출력합니다.
len(bs_obj.select("#wrap > div"))
# Out:
# 3

# %%
# ID가 wrap인 요소의 "모든 후손" 중에서 "모든 <div> 태그"를 찾습니다. (공백은 후손 선택자)
bs_obj.select("#wrap  div")
# Out:
# [<div id="mainMenuBox">
#  <ul>
#  <li><a href="#">패션잡화</a></li>
#  <li><a href="#">주방용품</a></li>
#  <li><a href="#">생활건강</a></li>
#  <li><a href="#">DIY가구</a></li>
#  </ul>
#  </div>,
#  <div>
#  <table>
#  <tr>
#  <td><img src="shoes1.jpg"/></td>
#  <td><img src="shoes2.jpg"/></td>
#  <td><img src="shoes3.jpg"/></td>
#  </tr>
#  <tr id="prdName">
#  <td>솔로이스트<br/>걸리쉬 리본단화</td>
#  <td>맥컬린<br/>그레이가보시스트랩 펌프스</td>
#  <td>맥컬린<br/>섹슈얼인사이드펌프스</td>
#  </tr>
#  <tr id="price">
#  <td>100,000원</td>
#  <td>200,000원</td>
#  <td>120,000원</td>
#  </tr>
#  </table>
#  </div>,
#  <div id="out_box">
#  <div class="box">
#  <h4>공지사항</h4>
#  <hr/>
#  <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a><br/>
#  <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a><br/>
#  <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>
#  </div>
#  <div class="box">
#  <h4>커뮤니티</h4>
#  <hr/>
#  <a href="#">[레시피] : 살 안찌는 야식 만들기</a><br/>
#  <a href="#">[가구] : 헌집 새집 베스트 가구</a><br/>
#  <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a><br/>
#  </div>
#  </div>,
#  <div class="box">
#  <h4>공지사항</h4>
#  <hr/>
#  <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a><br/>
#  <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a><br/>
#  <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>
#  </div>,
#  <div class="box">
#  <h4>커뮤니티</h4>
#  <hr/>
#  <a href="#">[레시피] : 살 안찌는 야식 만들기</a><br/>
#  <a href="#">[가구] : 헌집 새집 베스트 가구</a><br/>
#  <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a><br/>
#  </div>]

# %%
# 모든 후손 <div> 요소의 개수를 출력합니다.
# (총 4개: mainMenuBox, unnamed div, out_box, 2개의 box 클래스 -> 5개)
len(bs_obj.select("#wrap  div"))
# Out:
# 5

# %%
# 4. "클래스 선택자 및 데이터 추출" (Class Selector and Data Extraction)


# "클래스 이름이 'box'인 모든 요소"를 찾아 리스트로 반환합니다. (.은 클래스 선택자) (공지사항, 커뮤니티 2개)
bs_obj.select('.box')
# Out:
# [<div class="box">
#  <h4>공지사항</h4>
#  <hr/>
#  <a href="#">[배송] : 무표배송 변경 안내 18.10.20</a><br/>
#  <a href="#">[전시] : DIY 가구 전시 안내 18.10.31</a><br/>
#  <a href="#">[판매] : 11월 특가 상품 안내 18.11.05</a>
#  </div>,
#  <div class="box">
#  <h4>커뮤니티</h4>
#  <hr/>
#  <a href="#">[레시피] : 살 안찌는 야식 만들기</a><br/>
#  <a href="#">[가구] : 헌집 새집 베스트 가구</a><br/>
#  <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a><br/>
#  </div>]

# %%
# 클래스가 'box'인 요소의 개수를 출력합니다.
len(bs_obj.select('.box'))
# Out:
# 2

# %%
bs_obj.select('.box')[1].select('a')
# 1단계: 모든 '.box' 클래스를 찾아 리스트로 얻습니다.
# 2단계: 그 리스트의 "두 번째 요소" (인덱스 1, 커뮤니티 박스)를 선택합니다.
# 3단계: 선택된 요소 내부에서 "모든 <a> 태그"를 찾습니다. (커뮤니티 내 3개의 링크)
# Out:
# [<a href="#">[레시피] : 살 안찌는 야식 만들기</a>,
#  <a href="#">[가구] : 헌집 새집 베스트 가구</a>,
#  <a href="#">[후기] : 배송이 잘못 됐어요 ㅠㅠ</a>]

# %%
bs_obj.select('.box')[1].select('a')[0]
# 커뮤니티 박스 내부에서 찾은 <a> 태그 리스트의 "첫 번째 요소"를 선택합니다.
# (<a href="#">[레시피] : 살 안찌는 야식 만들기</a>)
# Out:
# <a href="#">[레시피] : 살 안찌는 야식 만들기</a>

# %%
bs_obj.select('.box')[0].select('a')[0].text
# 1단계: 첫 번째 '.box' (공지사항)를 선택합니다.
# 2단계: 그 내부의 첫 번째 'a' 태그를 선택합니다.
# 3단계: ".text" 속성을 사용하여 그 태그의 "순수한 텍스트"를 추출합니다. ('[배송] : 무표배송 변경 안내 18.10.20')
# Out:
# '[배송] : 무표배송 변경 안내 18.10.20'

# %%
bs_obj.select('.box')[0].select('a')[0]['href']
# 1단계: 첫 번째 '.box' (공지사항) 내부의 첫 번째 'a' 태그를 선택합니다.
# 2단계: "딕셔너리 접근" 방식(['href'])을 사용하여 'href' "속성 값"('#')을 추출합니다.


# "핵심 요약"
# select() 메서드는 CSS 선택자의 강력한 문법(ID: #, Class: ., Descendant: Space, Child: >)을 사용하여 
# find()/findAll() 보다 훨씬 명확하고 간결하게 HTML 요소를 검색할 수 있게 해줍니다. 
# 이 예시는 특정 박스(box 클래스) 내부의 링크만 추출하는 등 **"정밀한 영역 지정"**에 select()가 얼마나 유용한지를 보여줍니다.
# Out:
# '#'

# %%
# --------------------------------------------------
#     네이버 뉴스 크롤링
# --------------------------------------------------


# --- URL 연결 및 응답 객체 확인 ---
url_news = 'https://news.naver.com'  # 크롤링할 네이버 뉴스의 URL

# Naver로 HTTP GET 요청을 보내고, 응답(Response 객체)을 'naver_news_res' 변수에 저장
naver_news_res = requests.get(url_news)

# 응답 객체의 'status_code'를 출력하여 요청이 성공했는지 확인
# "200"이면 요청이 성공적이라는 의미
print(naver_news_res.status_code)
# Out:
# 200

# %%
# HTML 콘텐츠 추출 (응답 객체의 텍스트 형태로 HTML 내용 가져오기)
news_content = naver_news_res.text

# --- BeautifulSoup 객체 생성 및 타입 확인 ---
# 가져온 HTML 콘텐츠를 BeautifulSoup을 사용하여 파싱
bs_news = bs4.BeautifulSoup(news_content, 'html.parser')

# BeautifulSoup 객체의 타입을 출력하여 객체가 잘 생성되었는지 확인
print(type(bs_news))  # <class 'bs4.BeautifulSoup'>이 출력되어야 함
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
# 웹 스크래핑에 용이한 형태로 HTML 구조를 보기 위해 'prettify()' 메서드 사용
# 이를 통해 HTML 구조를 들여쓰기가 적용된 보기 쉬운 형태로 출력
print(bs_news.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko">
#  <head>
#   <title id="browserTitleArea">
#    네이버 뉴스
#   </title>
#   <script>
#    function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
#   </script>
#   <script>
#    (function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
#   </script>
#   <script>
#    var g_ssc = 'news.v3_media' || null;
# 		var bSupportedIntersectionObserver = "IntersectionObserver" in window;
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no,target-densitydpi=medium-dpi" name="viewport">
#    <link href="https://ssl.pstatic.net/static.news/mnews/resources/20251204_011133/css/generated/newshome.css" rel="stylesheet" type="text/css"/>
#    <link href="https://mimgnews.pstatic.net/image/news/m/2023/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <script>
#     (function(){
# 		var userAgent = navigator.userAgent;
# 		var result = [];
#
# 		if(userAgent.indexOf('Android') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPhone') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="120X120" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_2x_120X120.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_3x_180X180.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPad') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPadPro_2x_167X167.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPad_2x_152X152.png" />'
# 			];
# 		}
# 		document.write(result.join('\n'));
# 	})();
#    </script>
#    <script src="https://ssl.pstatic.net/static.news/mnews/resources/20251204_011133/js/generated/statistics_jquery.js" type="text/javascript">
#    </script>
#    <script>
#     document.documentElement.setAttribute('data-useragent',navigator.userAgent);
#    </script>
#    <script>
#     document.documentElement.setAttribute('data-useragent', navigator.userAgent);
#
#
# function showNoImage(elImg, type) {
#     switch (type) {
#
#         case "remove":
#             try {
#                 elImg.parentNode.removeChild(elImg);
#             } catch(e) {}
#             break;
#
#
#         case "removeParent":
#             try {
#                 elImg.parentNode.outerHTML = '';
#             } catch(e) {}
#             break;
#
#
#         case "alt":
#             elImg.outerHTML = ('<span class="noimage_text {imgClassName}">' + (elImg.alt || "") + '</span>')
#
#                 .replace('{imgClassName}', elImg.className);
#             break;
#
#
# 		case "class" :
# 			var outerHTMLSource = Number(elImg.getAttribute("height")) > 0?
#
# 				'<span class="noimage_wrap {imgClassName}" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
# 				'<span class="noimage_wrap {imgClassName}"><span class="noimage"></span></span>';
# 			elImg.outerHTML = outerHTMLSource.replace('{imgClassName}', elImg.className);
# 			break;
#
#         case "pressname" :
#             var pressname = elImg.getAttribute("data-pressname");
#             elImg.outerHTML = '<span class="cnb_broadcast_noimg"><span class="noimg_text">' + pressname + '</span></span>';
#             break;
#
#         case "noHeight":
#
#             elImg.outerHTML = '<span class="noimage_wrap"><span class="noimage"></span></span>';
#             break;
#
#         case "displayFallback":
#             elImg.style.display = "none";
#             var elWrapper = elImg.closest("._NOIMAGE_WRAPPER");
#             if (elWrapper) {
#                 var elFallback = elWrapper.querySelector("._NOIMAGE_FALLBACK");
#                 if (elFallback) {
#                     elFallback.style.display = "block";
#                 }
#             }
#             break;
#
#
#         default:
#
#             elImg.outerHTML = Number(elImg.getAttribute("height")) > 0?
#
#                 '<span class="noimage_wrap" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
#                 '<span class="noimage_wrap"><span class="noimage"></span></span>';
#     }
# }
#
#
# function doAfterLoadEnd(callback, callbackOnPersisted) {
#     var eventName = "onpageshow" in window ? "pageshow" : "load";
#
#     callback = callback || function(){};
#     callbackOnPersisted = callbackOnPersisted || function(){};
#
#     window.addEventListener(eventName, function(e) {
#         try{
#             if(Boolean(e.persisted)){
#                 callbackOnPersisted();
#                 return;
#             }
#         }catch(e){}
#
#         callback();
#     });
# }
#    </script>
#    <meta content="네이버 뉴스" property="og:title"/>
#    <meta content="website" property="og:type"/>
#    <meta content="https://news.naver.com/main/home.naver" property="og:url"/>
#    <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
#    <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" property="og:description"/>
#    <meta content="네이버" property="og:article:author"/>
#    <meta content="summary" name="twitter:card"/>
#    <meta content="네이버 뉴스" name="twitter:title"/>
#    <meta content="네이버 뉴스" name="twitter:site"/>
#    <meta content="네이버 뉴스" name="twitter:creator"/>
#    <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
#    <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" name="twitter:description"/>
#    <script>
#     (function () {
#         var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#         if (!isUnderIE10) {
#             var script = document.createElement("script");
#             script.async = true;
#             script.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#             document.head.appendChild(script);
#         }
#     })();
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#     window.gladsdk.cmd.push(function () {
#
#         window.gladsdk.setGlobalConfig({
#             enablePersistAd: true
#         });
#
#
#         var adUnits = [];
#
#         adUnits.push({
#             adUnitId: "p_news_sidebox",
#             adSlotElementId: "glad_ad_sidebox",
#             customParam: {
#                 calp: "home"
#             }
#         });
#         adUnits.push({
#             adUnitId: "p_news_sidebox",
#             adSlotElementId: "glad_ad_sidebox_secondary",
#             customParam: {
#                 calp: "home"
#             }
#         });
#
#         for (let i = 0; i < adUnits.length; i++) {
#             window.gladsdk.defineAdSlot(adUnits[i]);
#         }
#
#
#         var htmlClass = document.querySelector("html").getAttribute("class");
#         if (htmlClass && htmlClass.indexOf("DARK_THEME") > -1) {
#             window.gladsdk.setHostMeta("theme", "system");
#         }
#     });
#    </script>
#   </meta>
#  </head>
#  <body class="as_mp_layout body_main">
#   <div class="u_skip">
#    <a href="#ct">
#     본문 바로가기
#    </a>
#   </div>
#   <!-- Menu 구분  -->
#   <section class="news_header">
#    <header class="nh_header" role="banner">
#     <div class="Ngnb">
#      <div class="Ngnb_inner">
#       <div class="Ngnb_both">
#        <div class="Ngnb_left">
#         <span class="Ngnb_logo">
#          <a class="Nlogo_link" href="https://www.naver.com" onclick="nclk(event,'gnb.naver','','');">
#           <span class="Nicon_logo">
#            NAVER
#           </span>
#          </a>
#         </span>
#         <div class="Ngnb_service">
#          <h1 class="Nservice_item">
#           <a href="https://news.naver.com" onclick="nclk(event,'gnb.news','','');">
#            <span class="Nicon_service">
#             뉴스
#            </span>
#           </a>
#          </h1>
#          <span class="Nservice_subitem">
#           <a href="https://entertain.naver.com/home" onclick="nclk(event,'gnb.enter','','');">
#            <span class="Nicon_family Nicon_entertain">
#             엔터
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://sports.news.naver.com/index" onclick="nclk(event,'gnb.sports','','');">
#            <span class="Nicon_family Nicon_sports">
#             스포츠
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://weather.naver.com/" onclick="nclk(event,'gnb.weather','','');">
#            <span class="Nicon_family Nicon_weather">
#             날씨
#            </span>
#           </a>
#          </span>
#          <span class="Nservice_subitem">
#           <a href="https://contents.premium.naver.com/" onclick="nclk(event,'gnb.premium','','');">
#            <span class="Nicon_family Nicon_premium">
#             프리미엄
#            </span>
#           </a>
#          </span>
#         </div>
#        </div>
#        <div class="Ngnb_right">
#         <div class="Ngnb_group">
#          <div class="gnb_dark_type2" id="gnb">
#          </div>
#         </div>
#         <div class="Ngnb_search is_hidden _search_content">
#         </div>
#         <div class="Ngnb_tool">
#          <a class="Ntool_button _search_content_toggle_btn" href="javascript:;" onclick="nclk(event,'gnb.sch','','');">
#           <span class="Nicon_search">
#            검색
#           </span>
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="Nlnb _float_lnb">
#      <div class="Nlnb_inner">
#       <div class="Nlnb_both">
#        <div class="Nlnb_left _lnb_scroll">
#         <div class="Nlnb_menu Ntype_scroll">
#          <div class="Nlnb_menu_inner _scroll">
#           <ul class="Nlnb_menu_list" role="menu">
#            <li class="Nlist_item is_active">
#             <a aria-selected="true" class="Nitem_link" href="https://news.naver.com/?viewType=pc" onclick="nclk(event,'lnb.pcmedia','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               언론사별
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/100" onclick="nclk(event,'lnb.pol','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               정치
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/101" onclick="nclk(event,'lnb.eco','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               경제
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/102" onclick="nclk(event,'lnb.soc','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               사회
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/103" onclick="nclk(event,'lnb.lif','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               생활/문화
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/105" onclick="nclk(event,'lnb.sci','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               IT/과학
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/section/104" onclick="nclk(event,'lnb.wor','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               세계
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ranking/popularDay.naver" onclick="nclk(event,'lnb.rank','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               랭킹
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/newspaper/home?viewType=pc" onclick="nclk(event,'lnb.paper','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               신문보기
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/opinion/home" onclick="nclk(event,'lnb.opi','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               오피니언
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/tv/index.naver?mid=tvh" onclick="nclk(event,'lnb.tv','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               TV
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/factcheck/main" onclick="nclk(event,'lnb.fact','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               팩트체크
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item">
#             <a aria-selected="false" class="Nitem_link" href="https://media.naver.com/algorithm" onclick="nclk(event,'lnb.algo','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               알고리즘 안내
#              </span>
#             </a>
#            </li>
#            <li class="Nlist_item _isNew">
#             <a aria-selected="false" class="Nitem_link" href="https://news.naver.com/ombudsman/errorArticleList" onclick="nclk(event,'lnb.correct','','');" role="menuitem">
#              <span class="Nitem_link_menu">
#               정정보도 모음
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#   </section>
#   <hr/>
#   <div class="main_wrap" id="ct" role="main">
#    <div class="main_container">
#     <section class="main_content">
#      <h3 class="blind">
#       콘텐츠
#      </h3>
#      <div class="main_sublnb">
#       <div class="main_sublnb_date">
#        <strong>
#         12
#        </strong>
#        .
#        <strong>
#         5
#        </strong>
#        <span>
#         (금)
#        </span>
#       </div>
#       <ul class="main_sublnb_menu">
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://news.naver.com/main/officeList.naver " onclick="nclk(event, 'slb.allmedia', '', '')">
#          전체 언론사
#         </a>
#        </li>
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://newsstand.naver.com/" onclick="nclk(event, 'slb.newsstand', '', '')" target="_blank">
#          뉴스스탠드
#         </a>
#        </li>
#        <li class="main_sublnb_item">
#         <a class="main_sublnb_link" href="https://newslibrary.naver.com/search/searchByDate.naver" onclick="nclk(event, 'slb.library', '', '')" target="_blank">
#          라이브러리
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="main_brick">
#       <!-- BRICK HOUSE -->
#       <div class="grid1_wrap brick-house _brick_gid_wrapper">
#        <div class="brick-vowel _brick_column">
#         <div class="main_brick_item _press_main_status_wrapper">
#          <div class="comp_journal_subscribe">
#           <div class="cjs_title_wrap">
#            <h3 class="cjs_edit_title">
#             <span class="cjs_main">
#              언론사편집
#             </span>
#             <a class="cjs_subscribe_a" href="#feedJournalistCard" onclick="nclk(event, 'home.editassetting1', '', '')">
#              <span class="subs_text">
#               기자
#              </span>
#             </a>
#             <a class="cjs_subscribe_a" href="#feedSeriesCard" onclick="nclk(event, 'home.editassetting2', '', '')">
#              <span class="subs_text">
#               연재
#              </span>
#             </a>
#            </h3>
#            <a class="cjs_more_link" href="https://media.naver.com/channel/settings" onclick="nclk(event, 'home.editsetting', '', '')">
#             구독설정
#             <span class="ico_more">
#             </span>
#            </a>
#           </div>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/657" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/657/2025/03/07/logo_657_100_20250307145654.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18"/>
#             </div>
#             <em class="cnf_journal_name">
#              대구MBC
#             </em>
#             <span class="cnf_journal_sub">
#              12월 05일 17:48
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="657" data-office_name="대구MBC" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/657/0000045774" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/657/2025/12/05/45774.jpg?type=nf168_108&amp;ut=20251205174609" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             개인정보 훔치고 수능 후 자수한 '간 큰' 대구 고등학생들···경찰, 입건 전 조사
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/657/0000045753" onclick="nclk(event, 'home.editnfimg', '', '')">
#              권영진 "이대로 가면 2026년 선거에서 참패···윤석열, 조용히 있어야"
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/657/0000045751" onclick="nclk(event, 'home.editnfimg', '', '')">
#              [속보] '정치자금법 위반' 윤석준 대구 동구청장, 2심도 당선무효형
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/657/0000045770" onclick="nclk(event, 'home.editnfimg', '', '')">
#              정의당 "윤석준 대구 동구청장은 책임지고 물러나라"
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/629" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/629/2025/03/07/logo_629_100_20250307145723.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              더팩트
#             </em>
#             <span class="cnf_journal_sub">
#              12월 05일 18:03
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="629" data-office_name="더팩트" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/629/0000450687" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/629/2025/12/05/450687.jpg?type=nf168_108&amp;ut=20251205175612" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             정청래, '1인 1표제' 부결에 "당원에 사과…즉시 재추진 어려워"
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/629/0000450605" onclick="nclk(event, 'home.editnfimg', '', '')">
#              조희대 "사법제도 개편 신중해야"…전국법원장회의 시작
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/629/0000450477" onclick="nclk(event, 'home.editnfimg', '', '')">
#              '원조 친윤' 윤한홍, 尹·극우 절연 주장…장동혁 겨냥 비판도
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/629/0000450604" onclick="nclk(event, 'home.editnfimg', '', '')">
#              나경원 "與, 사법 파괴를 사법개혁으로 불러…가증스럽다"
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/003" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/003/2025/03/07/logo_003_100_20250307145615.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              뉴시스
#             </em>
#             <span class="cnf_journal_sub">
#              12월 05일 18:52
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="003" data-office_name="뉴시스" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/003/0013642459" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/003/2025/12/05/13642459.jpg?type=nf168_108&amp;ut=20251205183116" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             이 대통령, 강형석 농식품부 차관 직권면직…"부당하게 권한 행사"(종합)
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/003/0013642443" onclick="nclk(event, 'home.editnfimg', '', '')">
#              "해외 가면 큰 돈"…캄보디아로 韓2명 넘긴 일당, 재판행
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/003/0013642471" onclick="nclk(event, 'home.editnfimg', '', '')">
#              클라우드플레어, 서비스 장애 16분만에 초기 복구…"결과 모니터링 중"(종합2보)
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/003/0013642477" onclick="nclk(event, 'home.editnfimg', '', '')">
#              내년 '민원실 점심시간 휴무제'…"대구 북구, 재검토해야"
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/002" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/002/2025/03/07/logo_002_100_20250307145612.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              프레시안
#             </em>
#             <span class="cnf_journal_sub">
#              12월 05일 18:27
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="002" data-office_name="프레시안" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002417525" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/002/2025/12/05/2417525.jpg?type=nf168_108&amp;ut=20251205145015" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             장동혁 면전서 국힘 의원 "똥 묻은 개가 겨 묻은 개 비판하는 꼴이니…"
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002417598" onclick="nclk(event, 'home.editnfimg', '', '')">
#              '6단계 다크패턴' 뚫고 '탈팡' 본격화?…쿠팡 이용자, 나흘만에 감소세
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002417590" onclick="nclk(event, 'home.editnfimg', '', '')">
#              李대통령, 농식품부 차관 직권면직…"부당 권한행사·부적절 처신"
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002417610" onclick="nclk(event, 'home.editnfimg', '', '')">
#              "막대한 공적자금, 전력·용수까지 재벌에 줘야 하나…반특법 멈춰야"
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/021" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/021/2025/03/07/logo_021_100_20250307145703.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              문화일보
#             </em>
#             <span class="cnf_journal_sub">
#              12월 05일 18:47
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="021" data-office_name="문화일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/021/0002755175" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/021/2025/12/05/2755175.jpg?type=nf168_108&amp;ut=20251205173111" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             [속보]“광주 원룸 갇혔다” 출동했더니 건물 전체 ‘성매매 현장’
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/021/0002755179" onclick="nclk(event, 'home.editnfimg', '', '')">
#              “李정권 내란몰이 ‘올인’은 다른 것 할 줄 몰라서” 장동혁의 말
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/021/0002755041" onclick="nclk(event, 'home.editnfimg', '', '')">
#              “대치동 안가고 해냈다” 수능만점 지방 2개교 어디?…서울은 광남·세화
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/021/0002754972" onclick="nclk(event, 'home.editnfimg', '', '')">
#              “단둘이 어색해서…” 형부 30분 집 앞 세워둔 처제 ‘갑론을박’
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/658" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/658/2025/03/11/logo_658_100_20250311140757.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              국제신문
#             </em>
#             <span class="cnf_journal_sub">
#              12월 05일 18:53
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="658" data-office_name="국제신문" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/658/0000128236" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/658/2025/12/05/128236.jpg?type=nf168_108&amp;ut=20251205172210" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             [속보] 정청래, 1인1표제 부결에 “당원에 사과…당분간 재부의 어렵다”
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/658/0000128226" onclick="nclk(event, 'home.editnfimg', '', '')">
#              영국 기업 Arm, 한국 반도체 설계인력 1400명 키운다(종합)
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/658/0000128234" onclick="nclk(event, 'home.editnfimg', '', '')">
#              부산·울산·경남·대구·경북지역 학교 24%, 파업에 급식 차질
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/658/0000128224" onclick="nclk(event, 'home.editnfimg', '', '')">
#              한국영어관련학술단체협 "영어 절대평가 방식 폐지해야"
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/036" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/036/2025/03/07/logo_036_100_20250307145600.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              한겨레21
#             </em>
#             <span class="cnf_journal_sub">
#              12월 05일 17:15
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="036" data-office_name="한겨레21" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/036/0000052756" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/036/2025/12/05/52756.jpg?type=nf168_108&amp;ut=20251205085813" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             [단독] 세운4구역 고층 빌딩 설계, 희림 등과 520억원 수의계약
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/036/0000052759" onclick="nclk(event, 'home.editnfimg', '', '')">
#              ‘공학 전환’ 재추진, 동덕여대 혼돈 속으로
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/036/0000052758" onclick="nclk(event, 'home.editnfimg', '', '')">
#              1년 전보다 심해진 윤석열‘들’의 망상
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/036/0000052754" onclick="nclk(event, 'home.editnfimg', '', '')">
#              하루가 끝나고 남은 저녁 시간, 인생에서 남은 날들
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/666" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2025/03/07/logo_666_100_20250307145718.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              경기일보
#             </em>
#             <span class="cnf_journal_sub">
#              12월 05일 18:23
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="666" data-office_name="경기일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/666/0000089838" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/666/2025/12/05/89838.jpg?type=nf168_108&amp;ut=20251205182112" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             정청래, ‘1인1표제’ 부결에 “당분간 재부의 어렵지만 포기 안해”
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/666/0000089834" onclick="nclk(event, 'home.editnfimg', '', '')">
#              [속보] 김은혜 "대장동·대북송금·대통령실 현지…'3대' 막느라 미래 놓쳐"
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/666/0000089822" onclick="nclk(event, 'home.editnfimg', '', '')">
#              李대통령, 농식품부 차관 직권면직…"부당한 권한 행사"
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/666/0000089805" onclick="nclk(event, 'home.editnfimg', '', '')">
#              [단독] "딸이 아내 때려서"…딸 살해하려 한 70대 아버지 체포
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/001" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/001/2025/03/07/logo_001_100_20250307145612.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              연합뉴스
#             </em>
#             <span class="cnf_journal_sub">
#              12월 05일 18:30
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="001" data-office_name="연합뉴스" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/001/0015781817" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/001/2025/12/05/15781817.jpg?type=nf168_108&amp;ut=20251205174616" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             '기강 잡기' 나선 李대통령…공직사회 동요·불만 차단 포석
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/001/0015781829" onclick="nclk(event, 'home.editnfimg', '', '')">
#              정청래, '1인1표제' 부결에 "당분간 재부의 어렵지만 포기 안해"
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/001/0015781831" onclick="nclk(event, 'home.editnfimg', '', '')">
#              교육부, '불'영어 논란에 "출제·검토 과정 조사…엄정 대응"
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/001/0015781864" onclick="nclk(event, 'home.editnfimg', '', '')">
#              경찰, 장경태 고소인 전 남친 소환…촬영 당시 상황 등 조사
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/655" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/655/2025/03/07/logo_655_100_20250307145649.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              CJB청주방송
#             </em>
#             <span class="cnf_journal_sub">
#              12월 05일 17:43
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="655" data-office_name="CJB청주방송" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000028673" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/655/2025/12/05/28673.jpg?type=nf168_108&amp;ut=20251205144509" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             이재명 대통령 취임 6개월...국정 지지율 62%
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000028674" onclick="nclk(event, 'home.editnfimg', '', '')">
#              장동혁 "李 정권은 약탈과 파괴, 李 구하기만 관심"
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000028671" onclick="nclk(event, 'home.editnfimg', '', '')">
#              청주서 전방 주시 소홀로 9중 추돌 사고...13명 부상
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000028672" onclick="nclk(event, 'home.editnfimg', '', '')">
#              김건희에 명품 가방 선물 김기현 아내 특검 출석...묵묵부답
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/417" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/417/2025/03/07/logo_417_100_20250307145657.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              머니S
#             </em>
#             <span class="cnf_journal_sub">
#              12월 05일 18:18
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="417" data-office_name="머니S" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/417/0001117637" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/417/2025/12/05/1117637.jpg?type=nf168_108&amp;ut=20251205150108" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             이동을 '경험'으로 바꾸다… 기아, 80주년 '미래 콘셉트카' 첫선
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/417/0001117684" onclick="nclk(event, 'home.editnfimg', '', '')">
#              "30% 달성" 빗썸, 공격적 프로모션으로 1년 새 점유율 '껑충'
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/417/0001117682" onclick="nclk(event, 'home.editnfimg', '', '')">
#              "중국계 자본이 국민 노후 관리인?"… 이지스운용 매각에 우려 커져
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/417/0001117643" onclick="nclk(event, 'home.editnfimg', '', '')">
#              "딸 둘 낳으면 현금 준다"…  '성비 불균형'  베트남의 특단 대책
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="main_brick_item _channel_main_news_card_wrapper">
#          <div class="comp_news_feed comp_news_none">
#           <div class="cnf_journal_area">
#            <a class="cnf_journal" href="https://media.naver.com/press/005" onclick="nclk(event, 'home.editnfmedia', '', '')">
#             <div class="cnf_journal_thumb">
#              <img alt="" data-src="https://mimgnews.pstatic.net/image/upload/office_logo/005/2025/03/07/logo_005_100_20250307145616.png?type=nf36_36" height="18" loading="lazy" onerror="showNoImage(this)" width="18">
#              </img>
#             </div>
#             <em class="cnf_journal_name">
#              국민일보
#             </em>
#             <span class="cnf_journal_sub">
#              12월 05일 18:48
#             </span>
#            </a>
#            <button class="cnf_btn_subscription _subscribe_btn" data-office_id="005" data-office_name="국민일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">
#             <span class="blind">
#              구독
#             </span>
#            </button>
#           </div>
#           <a class="cnf_news_area _cds_link _editn_link" href="https://n.news.naver.com/article/005/0001818629" onclick="nclk(event, 'home.editnfimg', '', '')">
#            <div class="cnf_news_thumb">
#             <img alt="" data-src="https://mimgnews.pstatic.net/image/origin/005/2025/12/05/1818629.jpg?type=nf168_108&amp;ut=20251205020812" height="54" loading="lazy" onerror="showNoImage(this)" width="80"/>
#            </div>
#            <strong class="cnf_news_title">
#             젖은 담요로 3개월 아기 구한 가사도우미… 홍콩 화재 ‘숨은 영웅’
#            </strong>
#           </a>
#           <ul class="cnf_news_list">
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/005/0001818703" onclick="nclk(event, 'home.editnfimg', '', '')">
#              경찰, 박나래 상해 입건…‘매니저 갑질 의혹’ 수사
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/005/0001818736" onclick="nclk(event, 'home.editnfimg', '', '')">
#              조진웅 ‘소년범’ 의혹 일파만파…차량 절도, 성폭력까지?
#             </a>
#            </li>
#            <li class="cnf_news_item">
#             <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/005/0001818752" onclick="nclk(event, 'home.editnfimg', '', '')">
# ...
#             </picture>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="brick-vowel _brick_column">
#        </div>
#        <div class="brick-vowel _brick_column">
#        </div>
#       </div>
#      </div>
#     </section>
#     <section class="main_aside _aside_wrapper">
#      <div class="main_aside_inner _aside_content">
#       <h3 class="blind">
#        구독
#       </h3>
#       <div class="_aside">
#       </div>
#       <script>
#        doAfterLoadEnd(loadAside);
#
#
# function loadAside() {
#     var forcePcVersion = "";
#
#     if (isMobileDevice() && !forcePcVersion) {
#         return;
#     }
#     var iframe = append();
#     var asideFixed;
#
#     window.addEventListener('message', function(event) {
#         var data = event.data;
#
#         if (event.origin !== "https://news.naver.com") {
#             return;
#         }
#
#         if (data.type === "setIframeSize" && data.height) {
#             iframe.style.height = data.height + 'px';
#             iframe.style.visibility = "";
#
#             try {
#                 asideFixed.deactivate(); // event 중복 적용되지 않게
#             } catch(e) {}
#
#             asideFixed = AsideFixed({
#                 "wrapper" : document.querySelector("._aside_wrapper")
#
#             });
#         }
#     });
#
#
#     function append() {
#         var iframe = document.createElement('iframe');
#
#         iframe.title = "구독 및 추천 채널";
#         iframe.width = "100%";
#         iframe.height = "0";
#         iframe.style.visibility = "hidden";
#         iframe.setAttribute("frameborder", "no");
#         iframe.setAttribute("scrolling", "no");
#         iframe.src = "https://news.naver.com/aside?oid=";
#
#         document.querySelector("._aside").appendChild(iframe);
#
#         return iframe;
#     }
# }
#       </script>
#      </div>
#     </section>
#     <div class="layer_toast" style="display: none">
#     </div>
#     <div class="layer_toast_journal_subscribe _subscribe_toast_layer" style="display: none">
#      <button class="lt_btn_set _subscribe_toast_btn" onclick="nclk(event, 'home.edittallchk', '', '')" type="button">
#      </button>
#     </div>
#    </div>
#   </div>
#   <!-- //ct -->
#   <hr/>
#   <div class="mp_footer">
#    <div class="f_maininfo">
#     <div class="f_maininfoinner">
#      <a class="r_pg_top _go_top" href="javascript:topPage();" id="goTop" onclick="nclk(event, 'fot.pctop', '', '');">
#       맨위로
#      </a>
#      <footer role="contentinfo">
#       <p class="u_cr">
#        <span class="u_ftm _footer_login">
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}' href="https://m.naver.com/services.html" onclick="nclk(event,'fot.serviceall','','');">
#           전체서비스
#          </a>
#         </span>
#        </span>
#        <span class="u_ftm">
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://news.naver.com/ombudsman","p":"https://news.naver.com/ombudsman"}' href="https://news.naver.com/ombudsman" onclick="nclk(event,'fot.guide','','');">
#           서비스안내
#          </a>
#         </span>
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://help.naver.com/alias/news/news_001.naver","p":"https://help.naver.com/alias/news/news_001.naver"}' href="https://help.naver.com/alias/news/news_001.naver" onclick="nclk(event,'fot.report','','');">
#           오류신고
#          </a>
#         </span>
#         <span class="u_cri u_cri_v1">
#          <a class="u_cra" data-mpurl='{"m":"https://help.naver.com/alias/news/news_007.naver","p":"https://help.naver.com/alias/news/news_007.naver"}' href="https://help.naver.com/alias/news/news_007.naver" onclick="nclk(event,'fot.help','','');">
#           고객센터
#          </a>
#         </span>
#        </span>
#        <span class="cr_rule">
#         <span class="cr_rulea">
#          청소년 보호 책임자 : 이정규
#         </span>
#        </span>
#        <span class="u_presscopy">
#         각 언론사가 직접 콘텐츠를 편집합니다.
#        </span>
#        <span class="u_copyright">
#         이 콘텐츠의 저작권은 저작권자 또는 제공처에 있으며, 이를 무단 이용하는 경우 저작권법 등에 따라 법적 책임을 질 수 있습니다.
#        </span>
#        <span class="u_naverlogo">
#         <a class="u_naverlogo_a" data-mpurl='{"m":"https://www.navercorp.com/","p":"https://www.navercorp.com/"}' href="https://www.navercorp.com/" id="nhnLink" onclick="nclk(event,'fot.navercorp','','');">
#          NAVER
#         </a>
#        </span>
#       </p>
#      </footer>
#     </div>
#    </div>
#   </div>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20251204_011133/js/generated/news.mobile.js" type="text/javascript">
#   </script>
#   <script src="https://ssl.pstatic.net/static.news/mnews/resources/20251204_011133/js/generated/pressmain.dependency.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var config = {
#         "neloCollectorUrl": "https://kr-col-ext.nelo.navercorp.com/_store",
#         "projectName": "P638fcb_news-mobile-front",
#         "host": "real"
#     }
#
#     try{
#         neloSender.init(config);
#     }catch(e){}
#   </script>
#   <script type="text/javascript">
#    /**
#  * 이 파일은 모바일 뉴스 서비스 전체 페이지에 적용되는 스크립트로써,
#  * 코드 추가 시 Front-End 성능 관점에서 주의를 요합니다.
#  */
# jQuery(window).on('load', function(){
#     setTimeout(onload, 10);
#
#     function onload(){
#         var oLnb = new news.Lnb('._lnb_scroll');
#         new news.ImageLazyLoader().load("img[data-src]");
#         new news.MoveTopButton("._go_top");
#
#
#         new news.HistoryManager().init("naver_mobile_news_history", "");
#
#         // iframe lazy-loading
#         (function(){
#             try {
#                 Array.prototype.slice.apply(document.querySelectorAll('iframe[data-src]'))
#                     .forEach(function(iframeEl) {
#                         var originSrc = iframeEl.getAttribute('data-src');
#                         if(originSrc) {
#                             iframeEl.setAttribute('src', originSrc);
#                         }
#                     });
#             }catch(e) {}
#         })();
#
#         if(typeof init === "function"){
#             init();
#         }
#
#         var cookie = news.Cookie.getInstance();
#         var isShownNewLnb = cookie.getItem("isShownNewLnb");
#         if(isShownNewLnb == null) {
#             isShownNewLnb = "Y";
#             cookie.setItem("isShownNewLnb", isShownNewLnb, 3650, "", "/");
#             $("._isNew").addClass("is_new");
#         }
#
#         {
#             var footerLogin = jQuery(document).find('._footer_login');
#             if(footerLogin <= 0) {
#                 return;
#             }
#
#             // 디바이스에 따라 로그인, 로그아웃 URL 분기
#             var loginUrl = "https://nid.naver.com/nidlogin.login";
#             var logoutUrl = "https://nid.naver.com/nidlogin.logout?";
#             if (news.Util.getAgentInfo().bMobileOrTablet) {
#                 loginUrl = "https://nid.naver.com/nidlogin.login?svctype=262144";
#                 logoutUrl = "https://nid.naver.com/nidlogin.logout?svctype=262144&";
#             }
#
#             if(news.LoginAssistor.isLoginUser()) {
#                 footerLogin.prepend('<span class="u_cri u_cri_v1"><a href="javascript:news.Util.logout(\''+logoutUrl+'url=\'+encodeURIComponent(location.href));" class="u_cra" id="news_logout" onclick="nclk(event,\'fot.logout\',\'\',\'\');" >로그아웃</a></span>')
#             }else {
#                 footerLogin.prepend('<span class="u_cri u_cri_v1"><a href="'+loginUrl+'" class="u_cra" id="news_login" onclick="nclk(event,\'fot.login\',\'\',\'\');" >로그인</a></span>')
#             }
#         }
#     }
# });
#   </script>
#   <script id="feedRefreshButtonTemplate" type="text/x-handlebars-template">
#    {{buttonText}}
#     <span class="paging">
#         <span class="blind">현재</span>{{currentPage}}
#         <em class="total"> / <span class="blind">전체</span>{{totalPage}}</em>
#     </span>
#   </script>
#   <script type="text/javascript">
#    try {
#         FeedCard($('._journalist_feed_card_wrapper'), 'journalist', 'https://m.news.naver.com');
#         FeedCard($('._series_feed_card_wrapper'), 'series', 'https://m.news.naver.com');
#         FeedAccordionIssueCard($('._issue_feed_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] FeedCard 스크립트 오류 " + e);
#     }
#
#     try {
#         BrickGridForEditByPress($("._brick_gid_wrapper"));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] BrickGridForEditByPress 스크립트 오류 " + e);
#     }
#
#     try {
#         PressMainStatusCard($('._press_main_status_wrapper'));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] PressMainStatusCard 스크립트 오류 " + e);
#     }
#
#     try {
#         NewsFlashCard($('._newsflash_wrapper'));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] NewsFlashCard 스크립트 오류 " + e);
#     }
#
#     try {
#
#
#         window.gladsdk.cmd.push(function () {
#             var adSlots = [];
#             adSlots.push(window.gladsdk.findAdSlot("glad_ad_sidebox"));
#             adSlots.push(window.gladsdk.findAdSlot("glad_ad_sidebox_secondary"));
#
#             var adDedupManager = window.gladsdk.setAdDeduplication("pressmain_ad");
#             if (isBackForwardNavigated()) {
#                 adDedupManager.restoreAds(adSlots);
#             } else {
#                 adDedupManager.displayAds(adSlots);
#             }
#
#
#             window.gladsdk.addEventListener(window.gladsdk.event.ERROR, function (ad, error) {
#                 var adSlot = ad.slot;
#                 var $adSlotElement = $("#" + adSlot.getAdSlotElementId());
#                 $adSlotElement.closest("._ad_card_wrapper").hide();
#             });
#
#             window.gladsdk.addEventListener(window.gladsdk.event.AD_LOADED, function (ad) {
#                 var adSlot = ad.slot;
#                 var $adSlotElement = $("#" + adSlot.getAdSlotElementId());
#                 $adSlotElement.closest("._ad_card_wrapper").show();
#             });
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] 광고 호출 스크립트 오류 " + e);
#     }
#
#     try {
#         $('._channel_news_card_wrapper').each(function () {
#             var wrapper = $(this);
#             ChannelNewsCard(wrapper, 'https://m.news.naver.com');
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] ChannelNewsCard 스크립트 오류" + e);
#     }
#
#     try {
#         ChannelMainNewsCard($('._channel_main_news_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] ChannelMainNewsCard 스크립트 오류 " + e);
#     }
#
#     try {
#         SubscribeBannerShortCard($('._short_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#         SubscribeBannerLongCard($('._long_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] SubscribeBannerCard 스크립트 오류 " + e);
#     }
#
#     try {
#         WeeklySpecialReportCard($('._weekly_special_report_card_wrapper'));
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] WeeklySpecialReportCard 스크립트 오류 " + e);
#     }
#
#     try {
#         $('._tab_card_wrapper').each(function () {
#             var wrapper = $(this);
#             TabCard(wrapper);
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] TabCard 스크립트 오류 " + e);
#     }
#
#     try {
#         $('._horizontal_card_wrapper').each(function () {
#             var wrapper = $(this);
#             HorizontalTypeCard(wrapper, 'https://m.news.naver.com');
#         });
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] HorizontalTypeCard 스크립트 오류 " + e);
#     }
#
#     try {
#         SpecialReportCard($('._special_report_card_wrapper'), 'https://m.news.naver.com');
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] SpecialReportCard 스크립트 오류 " + e);
#     }
#
#     ArticleLinkParamsAppender('news_media_pc');
#
#     // Impression
#     try {
#         news.Impression.getInstance().init();
#     } catch (e) {
#         neloSender.sendErrorToNelo("[PC 언론사별] Impression init 스크립트 오류 " + e);
#     }
#
#     new news.ImageLazyLoader().load("img[data-src]");
#   </script>
#   <script>
#    var gnb_service = 'news';
#     var gnb_logout = encodeURIComponent(location.href);
#     var gnb_template = 'gnb_utf8';
#     var gnb_brightness = 3;
#     var gnb_item_hide_option= 128;
#
#     doAfterLoadEnd(function () {
#         try {
#             GlobalMPUrlManager.init();
#         } catch (e) {}
#     });
#
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('#gnb') || isMobileDevice() === true) {
#             return;
#         }
#
#         var gnb_src = "https://ssl.pstatic.net/static.gn/templates/gnb_utf8?2025120518";
#
#         // GnbHelper를 이용하여 GNB Layer를 닫을 수 있도록 지원한다.
#         if (window.jindo) {
#             jindo.LazyLoading.load(
#                 gnb_src,
#                 function() {
#                     try {
#                         getGNB();
#                     } catch(e) {}
#                 },
#                 'utf-8'
#             );
#
#             jindo.$Fn(function (oEvent) {
#
#                 GnbHelper.attachClick(oEvent.$value().target);
#             }).attach(document, 'click');
#         } else if (window.jQuery) {
#             new news.JsLoader().
#                 load(
#                     [gnb_src],
#                     function() {
#                         try {
#                             getGNB();
#                         } catch(e) {}
#                     }
#                 );
#
#             $(document).on("click", function(event) {
#                 GnbHelper.attachClick(event.target);
#             });
#         }
#     });
#   </script>
#   <script>
#    doAfterLoadEnd(function() {
#         if (!document.querySelector('.news_header')){
#             return;
#         }
#
#         try {
#             GnbFloatingManager.init();
#         } catch (e) { }
#     });
#   </script>
#   <script>
#    doAfterLoadEnd(function() {
#     try {
#         new SearchAutoComplete({
#             content: document.querySelector("._search_content"),
#             contentToggleBtn: document.querySelector("._search_content_toggle_btn"),
#             isMobile: isMobileDevice(),
#             nClickType: "newsM"
#         });
#     } catch(e) {}
# });
#   </script>
#   <!-- LCS -->
#   <script type="text/javascript">
#    function initMa(){
#     var data = {
#         "service": "news",
#         "baseInfo": {
#             "category": (function(){
#
#                 var result = "언론사별(신규)";
#
#                 if(result !== ""){
#                     return result;
#                 }
#                 try{
#
#                     return document.querySelector('meta[property="og:title"]')
#                         .getAttribute('content')
#                         .replace(/[\s]*:+[\s]*네이버[\s]*뉴스/, '');
#                 }catch(e){
#                     return "";
#                 }
#             })()
#         },
#         "extraInfo": {}
#     };
#
#
#
#     try{
#         ma.init({
#             api: "https://ma.news.naver.com/l",
#             data: data
#         });
#     }catch(e){}
# }
#   </script>
#   <script type="text/javascript">
#    window.ntm_news = window.ntm_news || [];
#
#     doAfterLoadEnd(function () {
#         var ntmUrl = "https://ntm.pstatic.net/scripts/ntm_b7032129a433.js";
#
#
#
#
#
#         ntmInit(ntmUrl);
#     });
#   </script>
#   <script type="text/javascript">
#    // NLog pageview 전송
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jQuery(window).on(eventType, function() {
#         var sti = "";
#         var gdid = "";
#
#
#
#
#
#
#                 if (isMobileDevice()) {
#                     // mobile
#
#                         sti = "m_news";
#
#                 } else {
#                     // pc
#
#                 }
#
#
#
#         // ma 전송
#         try {
#             initMa();
#         } catch (e) {
#         }
#
#         ntmCustomPageViewSend({
#             sti: sti,
#             gdid: gdid
#         });
#     });
#   </script>
#   <!-- //LCS -->
#   <div id="videoWrap">
#   </div>
#  </body>
# </html>

# %%
# --- CSS 선택자 사용하여 데이터 추출 ---
# CSS 선택자를 이용해 네이버 뉴스에서 원하는 요소를 선택
# '.comp_news_none .cnf_news_list .cnf_news_item' 클래스들을 가진 요소를 선택
# 이 부분에서 반환되는 것은 해당 클래스에 맞는 모든 요소들의 리스트
bs_news.select('.comp_news_none .cnf_news_list .cnf_news_item')
# Out:
# [<li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/657/0000045753" onclick="nclk(event, 'home.editnfimg', '', '')">권영진 "이대로 가면 2026년 선거에서 참패···윤석열, 조용히 있어야"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/657/0000045751" onclick="nclk(event, 'home.editnfimg', '', '')">[속보] '정치자금법 위반' 윤석준 대구 동구청장, 2심도 당선무효형</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/657/0000045770" onclick="nclk(event, 'home.editnfimg', '', '')">정의당 "윤석준 대구 동구청장은 책임지고 물러나라"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/629/0000450605" onclick="nclk(event, 'home.editnfimg', '', '')">조희대 "사법제도 개편 신중해야"…전국법원장회의 시작</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/629/0000450477" onclick="nclk(event, 'home.editnfimg', '', '')">'원조 친윤' 윤한홍, 尹·극우 절연 주장…장동혁 겨냥 비판도</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/629/0000450604" onclick="nclk(event, 'home.editnfimg', '', '')">나경원 "與, 사법 파괴를 사법개혁으로 불러…가증스럽다"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/003/0013642443" onclick="nclk(event, 'home.editnfimg', '', '')">"해외 가면 큰 돈"…캄보디아로 韓2명 넘긴 일당, 재판행</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/003/0013642471" onclick="nclk(event, 'home.editnfimg', '', '')">클라우드플레어, 서비스 장애 16분만에 초기 복구…"결과 모니터링 중"(종합2보)</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/003/0013642477" onclick="nclk(event, 'home.editnfimg', '', '')">내년 '민원실 점심시간 휴무제'…"대구 북구, 재검토해야"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002417598" onclick="nclk(event, 'home.editnfimg', '', '')">'6단계 다크패턴' 뚫고 '탈팡' 본격화?…쿠팡 이용자, 나흘만에 감소세</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002417590" onclick="nclk(event, 'home.editnfimg', '', '')">李대통령, 농식품부 차관 직권면직…"부당 권한행사·부적절 처신"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/002/0002417610" onclick="nclk(event, 'home.editnfimg', '', '')">"막대한 공적자금, 전력·용수까지 재벌에 줘야 하나…반특법 멈춰야"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/021/0002755179" onclick="nclk(event, 'home.editnfimg', '', '')">“李정권 내란몰이 ‘올인’은 다른 것 할 줄 몰라서” 장동혁의 말</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/021/0002755041" onclick="nclk(event, 'home.editnfimg', '', '')">“대치동 안가고 해냈다” 수능만점 지방 2개교 어디?…서울은 광남·세화</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/021/0002754972" onclick="nclk(event, 'home.editnfimg', '', '')">“단둘이 어색해서…” 형부 30분 집 앞 세워둔 처제 ‘갑론을박’</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/658/0000128226" onclick="nclk(event, 'home.editnfimg', '', '')">영국 기업 Arm, 한국 반도체 설계인력 1400명 키운다(종합)</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/658/0000128234" onclick="nclk(event, 'home.editnfimg', '', '')">부산·울산·경남·대구·경북지역 학교 24%, 파업에 급식 차질</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/658/0000128224" onclick="nclk(event, 'home.editnfimg', '', '')">한국영어관련학술단체협 "영어 절대평가 방식 폐지해야"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/036/0000052759" onclick="nclk(event, 'home.editnfimg', '', '')">‘공학 전환’ 재추진, 동덕여대 혼돈 속으로</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/036/0000052758" onclick="nclk(event, 'home.editnfimg', '', '')">1년 전보다 심해진 윤석열‘들’의 망상</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/036/0000052754" onclick="nclk(event, 'home.editnfimg', '', '')">하루가 끝나고 남은 저녁 시간, 인생에서 남은 날들</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/666/0000089834" onclick="nclk(event, 'home.editnfimg', '', '')">[속보] 김은혜 "대장동·대북송금·대통령실 현지…'3대' 막느라 미래 놓쳐"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/666/0000089822" onclick="nclk(event, 'home.editnfimg', '', '')">李대통령, 농식품부 차관 직권면직…"부당한 권한 행사"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/666/0000089805" onclick="nclk(event, 'home.editnfimg', '', '')">[단독] "딸이 아내 때려서"…딸 살해하려 한 70대 아버지 체포</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/001/0015781829" onclick="nclk(event, 'home.editnfimg', '', '')">정청래, '1인1표제' 부결에 "당분간 재부의 어렵지만 포기 안해"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/001/0015781831" onclick="nclk(event, 'home.editnfimg', '', '')">교육부, '불'영어 논란에 "출제·검토 과정 조사…엄정 대응"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/001/0015781864" onclick="nclk(event, 'home.editnfimg', '', '')">경찰, 장경태 고소인 전 남친 소환…촬영 당시 상황 등 조사</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000028674" onclick="nclk(event, 'home.editnfimg', '', '')">장동혁 "李 정권은 약탈과 파괴, 李 구하기만 관심"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000028671" onclick="nclk(event, 'home.editnfimg', '', '')">청주서 전방 주시 소홀로 9중 추돌 사고...13명 부상</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/655/0000028672" onclick="nclk(event, 'home.editnfimg', '', '')">김건희에 명품 가방 선물 김기현 아내 특검 출석...묵묵부답</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/417/0001117684" onclick="nclk(event, 'home.editnfimg', '', '')">"30% 달성" 빗썸, 공격적 프로모션으로 1년 새 점유율 '껑충'</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/417/0001117682" onclick="nclk(event, 'home.editnfimg', '', '')">"중국계 자본이 국민 노후 관리인?"… 이지스운용 매각에 우려 커져</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/417/0001117643" onclick="nclk(event, 'home.editnfimg', '', '')">"딸 둘 낳으면 현금 준다"…  '성비 불균형'  베트남의 특단 대책</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/005/0001818703" onclick="nclk(event, 'home.editnfimg', '', '')">경찰, 박나래 상해 입건…‘매니저 갑질 의혹’ 수사</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/005/0001818736" onclick="nclk(event, 'home.editnfimg', '', '')">조진웅 ‘소년범’ 의혹 일파만파…차량 절도, 성폭력까지?</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/005/0001818752" onclick="nclk(event, 'home.editnfimg', '', '')">제동 걸린 정청래표 ‘당원주권’… 정 “약속 지키지 못해 송구하다”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/127/0000038536" onclick="nclk(event, 'home.editnfimg', '', '')">"언론보도는 언론중재법으로… 망법에 언론 예외규정 둬야"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/127/0000038535" onclick="nclk(event, 'home.editnfimg', '', '')">경향신문 임협 타결… 기본급 3.5% 인상, 성과급 100%</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/127/0000038534" onclick="nclk(event, 'home.editnfimg', '', '')">뉴스룸 여성 데스크 200명 첫 돌파… 3개사는 절반 넘어</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/374/0000478965" onclick="nclk(event, 'home.editnfimg', '', '')">주민번호 유출은 이례적…넷마블, 과징금 규모는?</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/374/0000479015" onclick="nclk(event, 'home.editnfimg', '', '')">李 'AI 기본사회' 구상…손정의 "다음은 초인공지능"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/374/0000478971" onclick="nclk(event, 'home.editnfimg', '', '')">SK하이닉스 콕 집어 지원받나? 첨단산업 규제완화 논란…왜</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/031/0000986919" onclick="nclk(event, 'home.editnfimg', '', '')">與 '1인1표제' 당헌 개정안 부결…'정청래 리더십' 타격 불가피[종합]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/031/0000986986" onclick="nclk(event, 'home.editnfimg', '', '')">日 언론 "트럼프, 美 '모범 동맹국'에 한국 포함·일본 제외할 것"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/031/0000986967" onclick="nclk(event, 'home.editnfimg', '', '')">"복제약 40% 인하 예고"⋯학계-제약업계 '딴소리' [현장]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/584/0000035593" onclick="nclk(event, 'home.editnfimg', '', '')">'백신 부정' 美 케네디 장관, 면역효과 높이는 알루미늄 보조제에 태클</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/584/0000035589" onclick="nclk(event, 'home.editnfimg', '', '')">한국인 유전체 AI로 분석해 치매 위험 조기 예측</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/584/0000035586" onclick="nclk(event, 'home.editnfimg', '', '')">지방선거 D-6개월 AI챗봇 경계령…'팩트'로 표심 바꾼다</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/262/0000018966" onclick="nclk(event, 'home.editnfimg', '', '')">“한국의 지정학적 불안이 감정적 충돌의 두 기둥 키웠다”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/262/0000018964" onclick="nclk(event, 'home.editnfimg', '', '')">“플라스틱 식민주의 멈춰주세요” 12세 소녀, 국제 환경 의제 흔들다</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/262/0000018963" onclick="nclk(event, 'home.editnfimg', '', '')">“집값 낮추겠다는 정부 공언 믿어선 안 돼…서울 집 사라”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/020/0003679670" onclick="nclk(event, 'home.editnfimg', '', '')">李 “집값 탓에 요새 욕 많이 먹어…보니까 대책이 없다”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/020/0003679612" onclick="nclk(event, 'home.editnfimg', '', '')">수능 만점 이하진군 “국어 어려워 중간에 나가야하나 생각도…”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/020/0003679574" onclick="nclk(event, 'home.editnfimg', '', '')">뜯은지 6개월 지나면 버려야…빨래 악취 원인은 ‘이것’ [알쓸톡]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/023/0003945183" onclick="nclk(event, 'home.editnfimg', '', '')">李 “서울 집값 욕먹는데 대책 없어... 충남·대전 통합해보면 어떨까”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/023/0003945151" onclick="nclk(event, 'home.editnfimg', '', '')">중학생 2명 살해 20대, 6년 전 성범죄 때도 SNS로 10대 꾀어내</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/023/0003945181" onclick="nclk(event, 'home.editnfimg', '', '')">광주 유일 수능 만점자, 알고보니 미분함수 10초만에 풀었던 그 학생</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/215/0001233502" onclick="nclk(event, 'home.editnfimg', '', '')">"서울이 이 정도였어"…런던은 '추락'</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/215/0001233508" onclick="nclk(event, 'home.editnfimg', '', '')">고개 숙인 한예종…'학폭 4호 처분' 합격생 입학 불허</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/215/0001233587" onclick="nclk(event, 'home.editnfimg', '', '')">"손정의, 美에 '트럼프 산업 단지' 만든다"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/024/0000101836" onclick="nclk(event, 'home.editnfimg', '', '')">‘현지 누나’ 파문 확산…야권 “특별감찰관 즉시 임명하라”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/024/0000101830" onclick="nclk(event, 'home.editnfimg', '', '')">두피 바르는 ‘탈모약’ 효과 대박...주가 ‘불기둥’</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/024/0000101833" onclick="nclk(event, 'home.editnfimg', '', '')">장래 지도자 선호도 2위 김민석...1위는?</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/018/0006178578" onclick="nclk(event, 'home.editnfimg', '', '')">‘불영어’에 1등급 비율 3%대 폭삭…평가원 결국 사과</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/018/0006178581" onclick="nclk(event, 'home.editnfimg', '', '')">손보사, 기습 폭설·결빙으로 전날 긴급출동 7만건…전년비 72%↑</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/018/0006178579" onclick="nclk(event, 'home.editnfimg', '', '')">"반도체 수출 호조, 올해는 물량 증가·내년은 가격 상승이 주도"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/057/0001923193" onclick="nclk(event, 'home.editnfimg', '', '')">"제설 엉망" 빙판에 시민들 출근길 분통…퇴근길 또 걱정 [짤e몽땅]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/057/0001923197" onclick="nclk(event, 'home.editnfimg', '', '')">수능 영어 1등급 3.11% 충격에 "절대평가 방식 폐지해야"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/057/0001923178" onclick="nclk(event, 'home.editnfimg', '', '')">"내 집 앞 눈은 내가"…임영웅, 훈훈한 제설작전</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/008/0005287985" onclick="nclk(event, 'home.editnfimg', '', '')">"70만원 못 받았다" 자기계발 플랫폼 '기습 파산'...사기 혐의 '고소'</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/008/0005287913" onclick="nclk(event, 'home.editnfimg', '', '')">"한 200만원 주웠다"…길바닥 뒤덮은 5만원권, 무슨 사연?</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/008/0005287978" onclick="nclk(event, 'home.editnfimg', '', '')">직구 시켜놓고 통관번호 재발급..."배송 지연" 세관 막힌 택배 수두룩</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/015/0005220825" onclick="nclk(event, 'home.editnfimg', '', '')">"전셋집 딱 하나 나왔대"…아파트 보러 갔다가 '멘붕'</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/015/0005220861" onclick="nclk(event, 'home.editnfimg', '', '')">"명품도 도망쳤다"…베이징 한복판마저 '여기 저기 텅텅'</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/015/0005220898" onclick="nclk(event, 'home.editnfimg', '', '')">"이름·주소 알아도 믿지 마세요"…쿠팡 사태 '2차 피해' 공포</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/123/0002373332" onclick="nclk(event, 'home.editnfimg', '', '')">야권, 인사청탁 파문에 “최순실-김건희 답습"...특별감찰관 임명 촉구</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/123/0002373327" onclick="nclk(event, 'home.editnfimg', '', '')">이 대통령 만난 손정의 회장 "첫째, 둘째, 셋째도 ASI 집중하라" 조언</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/123/0002373270" onclick="nclk(event, 'home.editnfimg', '', '')">"佛마크롱, 유럽 정상들에 '미국이 우크라이나 배신할 수 있다' 경고"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/033/0000049914" onclick="nclk(event, 'home.editnfimg', '', '')">수출 ‘마중물’로 변신하는 퇴역 함정들…장보고함에 이어 이천함도 대기[박성진의 국방 B컷](46)</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/033/0000049911" onclick="nclk(event, 'home.editnfimg', '', '')">‘현지누나’ 논란 김남국 사퇴에, 국힘 “전형적인 꼬리 자르기”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/033/0000049916" onclick="nclk(event, 'home.editnfimg', '', '')">검은 연기에 휩싸인 홍콩, 올 것이 왔다?[구정은의 수상한 GPS](19)</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/087/0001159709" onclick="nclk(event, 'home.editnfimg', '', '')">정청래 "윤석열, 뻔뻔한 자기 합리화…장동혁, 尹 궤변과 망언 재창·삼창 반복"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/087/0001159711" onclick="nclk(event, 'home.editnfimg', '', '')">조세호 측 "조폭 연관설은 제보자의 추측에 불과, 사실 아냐…법적 대응 적극 검토"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/087/0001159720" onclick="nclk(event, 'home.editnfimg', '', '')">취임 6개월 李대통령 지지율 62%…긍정 평가 이유로 32%가 '외교 잘했다' 꼽아</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/310/0000131939" onclick="nclk(event, 'home.editnfimg', '', '')">‘여성건강 4법’ 발의…의약품 임상부터 자살예방까지 성차 반영한다</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/310/0000131749" onclick="nclk(event, 'home.editnfimg', '', '')">“죽은 언니들 몫까지 싸우겠다”… 다시 소송에 나선 미군 ‘위안부’ 3인의 증언</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/310/0000131922" onclick="nclk(event, 'home.editnfimg', '', '')">청년 여성, 수도권으로 ‘생존 이동’…소득 25.5% 올라</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/437/0000467476" onclick="nclk(event, 'home.editnfimg', '', '')">이 대통령, 농식품부 차관 면직..."부당권한 행사·부적절 처신"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/437/0000467478" onclick="nclk(event, 'home.editnfimg', '', '')">정청래표 '1인1표제' 최종 부결…재적 과반 이상 찬성 못 얻어</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/437/0000467496" onclick="nclk(event, 'home.editnfimg', '', '')">'계엄놀이'라며 미화원 괴롭힌 공무원 구속…"도주 우려 등"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/640/0000081232" onclick="nclk(event, 'home.editnfimg', '', '')">Police receive almost 2,000 reports as snow brings surge of traffic accidents and congestion</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/640/0000081221" onclick="nclk(event, 'home.editnfimg', '', '')">APR's founder sees the beauty sector differently, from leaning into devices to viral marketing himself</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/640/0000081227" onclick="nclk(event, 'home.editnfimg', '', '')">Coupang’s daily active users fall for first time in four days as customers quit platform over data leak</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/138/0002211692" onclick="nclk(event, 'home.editnfimg', '', '')">소비자용 메모리 버리고 AI로…크루셜 접은 마이크론, D램 시장 흔들까 [소부장반차장]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/138/0002211694" onclick="nclk(event, 'home.editnfimg', '', '')">포스코홀딩스 "대규모 청정수소 공급 체계, 국가에서 확보해야"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/138/0002211679" onclick="nclk(event, 'home.editnfimg', '', '')">이재명 대통령, 손정의·암(Arm) CEO와 회동… “국가 역량 총결집해야”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/656/0000158293" onclick="nclk(event, 'home.editnfimg', '', '')">7년전 또래 여중생 집단 성폭행한 10대 4명…檢, 징역 14년 구형</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/656/0000158292" onclick="nclk(event, 'home.editnfimg', '', '')">영단협 "수능 영어 1등급 3.11%…절대평가 즉각 폐기해야"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/656/0000158295" onclick="nclk(event, 'home.editnfimg', '', '')">후배 성착취물 유포한 대전 고교 운동부 유망주…실업팀 입단 보류</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/088/0000985320" onclick="nclk(event, 'home.editnfimg', '', '')">화장실서 낳은 아기, 그대로 변기에…매정한 친모에 항소심도 '실형'</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/088/0000985319" onclick="nclk(event, 'home.editnfimg', '', '')">발신번호표시제한으로 "원룸에 갇혔어요" 신고…알고보니 원룸 전체가 성매매 현장</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/088/0000985289" onclick="nclk(event, 'home.editnfimg', '', '')">배우 조진웅, '강도·강간 소년범' 의혹…"사실 확인 중"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/025/0003487674" onclick="nclk(event, 'home.editnfimg', '', '')">"기형아 낳을까봐 인공유산"…역대 최악 공포 부른 '낙동강 재앙'  [창간기획 대한민국 '트리거60' &lt;58&gt;]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/025/0003487757" onclick="nclk(event, 'home.editnfimg', '', '')">36등으로 입학해 수능 만점 대박…폰게임 즐기던 '전주 고3' 비결 [인터뷰]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/025/0003487818" onclick="nclk(event, 'home.editnfimg', '', '')">"아내가 우래옥 고기도 사왔는데!"…한동훈 노려본 尹의 그날</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/665/0000006296" onclick="nclk(event, 'home.editnfimg', '', '')">실업급여로 1억원 수령? 불편한 '시럽 루프' [질문+]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/665/0000006292" onclick="nclk(event, 'home.editnfimg', '', '')">최상급이라더니 흠집이… '중고폰 복불복' 천태만상 [추적+]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/665/0000006297" onclick="nclk(event, 'home.editnfimg', '', '')">소비쿠폰 받자마자 음식점으로…13.5조원 99.8% 소진</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/016/0002568021" onclick="nclk(event, 'home.editnfimg', '', '')">[단독] 애플, 국토정보지리원에 서류 보완 요청…지도반출 심의 연기</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/016/0002567934" onclick="nclk(event, 'home.editnfimg', '', '')">한예종 결국 고개 숙였다…‘학폭 4호’ 합격생 입학 불허</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/016/0002567828" onclick="nclk(event, 'home.editnfimg', '', '')">“쿠팡, 괘씸” 탈퇴 힘들면 안 쓰면 된다…하루 이용자 18만명 급감</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/094/0000013131" onclick="nclk(event, 'home.editnfimg', '', '')">오리엔티어링의 '시작과 끝' 지도 [OMM JAPAN 즐기기]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/094/0000013130" onclick="nclk(event, 'home.editnfimg', '', '')">짐은 가볍게 필수품만, 10kg 미만으로 [OMM JAPAN 장비]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/094/0000013129" onclick="nclk(event, 'home.editnfimg', '', '')">임금이 타는 명마가 태어난 곳 [한라산 어승생악]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/011/0004564109" onclick="nclk(event, 'home.editnfimg', '', '')">李대통령 만난 손정의 "인류는 금붕어, AI가 인간될 것"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/011/0004563961" onclick="nclk(event, 'home.editnfimg', '', '')">"박나래가 술잔 던지고 폭언"…'갑질 의혹' 피소 이어 고발장까지 접수</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/011/0004563791" onclick="nclk(event, 'home.editnfimg', '', '')">"유튜버들도 여행 포기하더라"…세계에서 가장 더러운 나라 1위 '이곳', 한국은?</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/029/0002997733" onclick="nclk(event, 'home.editnfimg', '', '')">‘남녀공학 전환’ 동덕여대에 ‘칼부림 예고’ 10대女, 경찰 검거</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/029/0002997662" onclick="nclk(event, 'home.editnfimg', '', '')">“길바닥에 뿌려진 5만원권, 막 주웠다”…‘돈벼락’ 맞은 시민들, 횡재일까</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/029/0002997692" onclick="nclk(event, 'home.editnfimg', '', '')">[속보] 청주서 ‘블랙아이스’에 차량 9대 연쇄 추돌…13명 다쳐 병원行</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/659/0000039216" onclick="nclk(event, 'home.editnfimg', '', '')">전주시장 호주 출장 중 술자리 논란..전주시 "강경 대응"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/659/0000039214" onclick="nclk(event, 'home.editnfimg', '', '')">길 안 비켜줘서 폭행.. 뇌사상태 빠뜨린 오토바이 운전자 '긴급체포'</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/659/0000039192" onclick="nclk(event, 'home.editnfimg', '', '')">7세·9세 자매 성추행한 60대 학원기사.. 항소심서도 징역 6년</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/661/0000066591" onclick="nclk(event, 'home.editnfimg', '', '')">"똥 묻은 개가.." 이재명 성토하던 장동혁 면전서 윤한홍 "비판할 자격 갖췄나"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/661/0000066579" onclick="nclk(event, 'home.editnfimg', '', '')">"李 대통령 잘하고 있다" 지지율 62%.. 취임 6개월 '역대 3위'</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/661/0000066590" onclick="nclk(event, 'home.editnfimg', '', '')">"휴게공간도 없고 5년 버티기 어려워"...제주 숙박업 노동환경  심각</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/047/0002497457" onclick="nclk(event, 'home.editnfimg', '', '')">&lt;케데헌 2&gt;에는 한강이 나올 수 있을까?</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/047/0002497466" onclick="nclk(event, 'home.editnfimg', '', '')">[단독] "성교육이 성애화"?...혐오·우익 성향 단체, 학교에 공문</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/047/0002497450" onclick="nclk(event, 'home.editnfimg', '', '')">하남시 대표 캐릭터 굿즈 자판기, 미사역·하남시청역서 운영 시작</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/050/0000099242" onclick="nclk(event, 'home.editnfimg', '', '')">‘이재용·구광모의 남자들’ 전면 퇴장…‘2026 재계 리셋’의 의미</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/050/0000099261" onclick="nclk(event, 'home.editnfimg', '', '')">손정의 만난 李대통령 "한일 간 AI분야 가교 역할 해주셨으면" 당부</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/050/0000099269" onclick="nclk(event, 'home.editnfimg', '', '')">샘 올트먼, 테크 업계 라이벌 머스크와 이번엔 우주전쟁하나?</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/654/0000155221" onclick="nclk(event, 'home.editnfimg', '', '')">특검, 김건희 여사 오빠 10일 참고인 조사…양평고속도로 의혹 규명 속도</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/654/0000155204" onclick="nclk(event, 'home.editnfimg', '', '')">이재명 대통령 취임 6개월 기념 '대통령 손목시계' 공개</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/654/0000155225" onclick="nclk(event, 'home.editnfimg', '', '')">조세호, 조직폭력배 연루설 전면 부인…"허위 사실, 법적 대응 검토"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/056/0012080391" onclick="nclk(event, 'home.editnfimg', '', '')">‘당원 1인 1표제’ 예상밖 좌초…“정청래 리더십에 경고장”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/056/0012080367" onclick="nclk(event, 'home.editnfimg', '', '')">[단독] 서울 서대문구 대학 캠퍼스서 마약 취한 채 ‘비틀비틀’…30대 남성 체포</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/056/0012080370" onclick="nclk(event, 'home.editnfimg', '', '')">비욘세·테일러 스위프트급?…USC, K팝 최초 지드래곤 강좌 개설 [지금뉴스]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/366/0001128403" onclick="nclk(event, 'home.editnfimg', '', '')">‘1인 1표제’ 부결에 정청래 “투표율 저조해서… 당원 믿고 다시 전진”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/366/0001128343" onclick="nclk(event, 'home.editnfimg', '', '')">“갇혔어요” 신고에 출동한 원룸, 성매매 업소였다… 경찰, 40대 포주 체포</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/366/0001128330" onclick="nclk(event, 'home.editnfimg', '', '')">‘갑질 의혹’ 박나래, 상해 등 혐의로 경찰 입건</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/052/0002283194" onclick="nclk(event, 'home.editnfimg', '', '')">'한동훈 증인 신문' 끝내 무산...김건희 특검 소환도 불발될 듯</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/052/0002283172" onclick="nclk(event, 'home.editnfimg', '', '')">맞고소에 '장경태 방지법'까지...김남국 옹호론도</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/052/0002283174" onclick="nclk(event, 'home.editnfimg', '', '')">법원장 회의, 4시간째 진행...조희대 "신중해야"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/214/0001466244" onclick="nclk(event, 'home.editnfimg', '', '')">[단독] 특검, '서울-양평고속도로 특혜 의혹' 김건희 오빠에 10일 출석 통보</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/214/0001466207" onclick="nclk(event, 'home.editnfimg', '', '')">"계엄 어이없어" 태세 급전환‥흔들리는 장동혁 '동공지진'</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/214/0001466247" onclick="nclk(event, 'home.editnfimg', '', '')">환경미화원 상대 '계엄령 놀이' 강원 양양군 공무원 구속</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/469/0000901521" onclick="nclk(event, 'home.editnfimg', '', '')">이재명 정부 비판 자리가 '장동혁 성토장'으로 …소장파 이어 윤핵관마저 쓴소리</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/469/0000901464" onclick="nclk(event, 'home.editnfimg', '', '')">"대치동 안 가도 됩니다"… '수능 만점' 전주 한일고 이하진군</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/469/0000901458" onclick="nclk(event, 'home.editnfimg', '', '')">배우 조진웅 '강력범죄 소년범 출신' 의혹… 소속사 "확인 중"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/028/0002780065" onclick="nclk(event, 'home.editnfimg', '', '')">‘한국은 중국 막는 첨병’…미 국가안보전략서 명시</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/028/0002780063" onclick="nclk(event, 'home.editnfimg', '', '')">“똥 묻은 개”…찐윤마저 면전서 ‘계엄 사과’ 요구, 고립되는 장동혁</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/028/0002780035" onclick="nclk(event, 'home.editnfimg', '', '')">김상욱 “장동혁, 계엄 날 본회의장서 ‘미안하다, 면목 없다’ 해”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/082/0001356993" onclick="nclk(event, 'home.editnfimg', '', '')">부산 민주당 “박형준 보좌관, ‘아동 학대’ 의혹 유치원 이사장…반드시 심판해야”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/082/0001357048" onclick="nclk(event, 'home.editnfimg', '', '')">국민의힘 경남도당, 양산시와 정책협의회</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/082/0001357052" onclick="nclk(event, 'home.editnfimg', '', '')">[속보] 클라우드플레어, 또 일시 장애…일부 웹서비스·사이트 접속 오류</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/421/0008646112" onclick="nclk(event, 'home.editnfimg', '', '')">李대통령 "대전·충남 모범통합 해보자"…'지역 통합론' 띄웠다(종합)</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/421/0008646073" onclick="nclk(event, 'home.editnfimg', '', '')">최태원 "AI 거품 아냐…7년 이내 인프라 구축에 1400조 투자해야"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/421/0008646140" onclick="nclk(event, 'home.editnfimg', '', '')">"밤낮없이 와줘서 고마워"…건국대, 응급헌혈 영웅견에 특별한 선물</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/032/0003413421" onclick="nclk(event, 'home.editnfimg', '', '')">[속보] 이 대통령, 농식품부 차관 직권면직···“부당한 권한 행사”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/032/0003413441" onclick="nclk(event, 'home.editnfimg', '', '')">[속보]정청래, ‘1인 1표제’ 부결에 “당원들께 사과···지방선거 룰 개정은 다시 의결 밟겠다”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/032/0003413404" onclick="nclk(event, 'home.editnfimg', '', '')">배우 조진웅 ‘고교 시절 중범죄로 보호처분’ 의혹···소속사 “사실관계 확인 중”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/009/0005601724" onclick="nclk(event, 'home.editnfimg', '', '')">[속보] 3주 만에 또 클라우드플레어 장애…배민 접속오류</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/009/0005601718" onclick="nclk(event, 'home.editnfimg', '', '')">AI 넘어 ASI 가리킨 손정의…이재명 대통령과 70분간 협력논의</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/009/0005601722" onclick="nclk(event, 'home.editnfimg', '', '')">“외고가 대입에 유리”…서울 지역 외고 6곳 경쟁률 전년보다 상승</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/662/0000083729" onclick="nclk(event, 'home.editnfimg', '', '')">“임플란트 도중 추가비용 요구”…치과 진료비 분쟁 ‘급증’</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/662/0000083694" onclick="nclk(event, 'home.editnfimg', '', '')">‘사양벌꿀→설탕꿀’로 바뀌나…“고시개정안 12월 중 행정예고”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/662/0000083730" onclick="nclk(event, 'home.editnfimg', '', '')">“늦기전에 중증환자 판별”…‘당뇨병’ 새 분류기준 나왔다</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/243/0000089178" onclick="nclk(event, 'home.editnfimg', '', '')">주주 반발 속…BNK금융 “모범관행 따라 회장 선임 진행”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/243/0000089179" onclick="nclk(event, 'home.editnfimg', '', '')">80년 달려온 기아…전시·콘셉트카로 풀어낸 과거와 미래</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/243/0000089176" onclick="nclk(event, 'home.editnfimg', '', '')">'세계 매력적인 여행지' 1위는 파리…서울은?</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/006/0000133118" onclick="nclk(event, 'home.editnfimg', '', '')">李대통령 "김종철 후보, 새 조직 빠르게 안정시킬 수 있을 것"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/006/0000133124" onclick="nclk(event, 'home.editnfimg', '', '')">내란재판부·법왜곡죄…조희대 "피해 되돌리기 어려워" 천대엽 "삼권분립 침해"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/006/0000133123" onclick="nclk(event, 'home.editnfimg', '', '')">'민원사주 폭로' 류희림 퇴진 이끈 방미심위 노조 차기 집행부 출범</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/648/0000042443" onclick="nclk(event, 'home.editnfimg', '', '')">[인사이드 스토리]큰 그림 그리는 현대차…구조 변화 신호탄?</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/648/0000042444" onclick="nclk(event, 'home.editnfimg', '', '')">큐리어스, 이도에 3000억 투자…IPO 체질 만들기 돌입</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/648/0000042438" onclick="nclk(event, 'home.editnfimg', '', '')">삼성생명, 삼성화재 지분법 적용 논란도 종지부</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/448/0000575213" onclick="nclk(event, 'home.editnfimg', '', '')">李대통령, 강형석 농림부 차관 직권면직…"부당 권한행사 확인"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/448/0000575241" onclick="nclk(event, 'home.editnfimg', '', '')">與 전현희 "감사원 사과 높이 평가…'표적 감사' 주범들 책임 물어야"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/448/0000575230" onclick="nclk(event, 'home.editnfimg', '', '')">"길 안 비켜줘서"…30대 배달기사가 60대 운전자 때려 '뇌사'</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/296/0000095341" onclick="nclk(event, 'home.editnfimg', '', '')">“사고 쳤다”던 안선영, 달라진 얼굴 보니? “자연스러워지는 중”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/296/0000095352" onclick="nclk(event, 'home.editnfimg', '', '')">“2030도 푹 빠진 이유 있었네”…몸도 마음도 ‘사르르’ 녹는 여행지 4곳</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/296/0000095347" onclick="nclk(event, 'home.editnfimg', '', '')">사과, 요구르트 후식 아닌 '간식'으로 먹었더니…혈당, 체중에 어떤 변화가?</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/346/0000101369" onclick="nclk(event, 'home.editnfimg', '', '')">소개팅 성공률 높이려면… 상대에게 ‘이것’ 건네라</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/346/0000101359" onclick="nclk(event, 'home.editnfimg', '', '')">아내에게 ‘이 말’ 자주 하면, 관계 만족도 올리는 데 큰 도움</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/346/0000101358" onclick="nclk(event, 'home.editnfimg', '', '')">‘이 물’에 목욕하면, 운동만큼 심장 건강에 이득… 뭘까?</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/079/0004093212" onclick="nclk(event, 'home.editnfimg', '', '')">김현지 부속실장 "유탄 맞은 것…김남국과 '누나·동생' 아냐"[영상]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/079/0004093270" onclick="nclk(event, 'home.editnfimg', '', '')">'계엄령 놀이' 미화원에 갑질한 양양군 공무원 결국 구속…"증거인멸·도주 우려"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/079/0004093291" onclick="nclk(event, 'home.editnfimg', '', '')">특검, '조사 불응' 구세현 전 웰바이오텍 대표 체포해 조사</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/119/0003033740" onclick="nclk(event, 'home.editnfimg', '', '')">'원조 친윤' 윤한홍도 '尹절연·계엄 사과' 주장…"李정권 비판할 자격 갖춰야"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/119/0003033781" onclick="nclk(event, 'home.editnfimg', '', '')">1800만원 목걸이 훔치려고 '이 행동'까지 한 도둑...뭐길래?</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/119/0003033771" onclick="nclk(event, 'home.editnfimg', '', '')">윤영희 "추미애·김병주, 기승전 오세훈 탓…저열한 정치 행태"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/055/0001313740" onclick="nclk(event, 'home.editnfimg', '', '')">이 대통령 "요즘 욕 많이 먹는다" 정면돌파?…부동산 문제 언급하더니 [바로이뉴스]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/055/0001313750" onclick="nclk(event, 'home.editnfimg', '', '')">나 몰라라 하던 자녀 숨지자 "돈 달라"…사이다 결말 '환호' [자막뉴스]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/055/0001313673" onclick="nclk(event, 'home.editnfimg', '', '')">"연봉 3억 꿀직장" 몰린다…털리고도 또 중국인 채용</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/014/0005445011" onclick="nclk(event, 'home.editnfimg', '', '')">클라우드플레어 또 장애...리멤버·LoL 등 접속 오류</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/014/0005444765" onclick="nclk(event, 'home.editnfimg', '', '')">박나래에 유재석 "술 좀 끊었으면".."만취해 맨발로 거리 활보" 지인의 과거 발언 재조명</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/014/0005444684" onclick="nclk(event, 'home.editnfimg', '', '')">끝까지 쫓아가 흉기 휘둘렀다…'층간소음' 윗층 70대 살해한 40대 男</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/081/0003598533" onclick="nclk(event, 'home.editnfimg', '', '')">수Ⅱ 문제 5초 암산하더니 ‘정답’…수능 만점자, 유튜브 나왔다</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/081/0003598569" onclick="nclk(event, 'home.editnfimg', '', '')">李대통령 당부에 성과로 보여준 김병기…예산안 ‘시한 내 통과’ 약속지켰다 [주간 여의도 Who?]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/081/0003598566" onclick="nclk(event, 'home.editnfimg', '', '')">“이 다 뽑았는데 의사가 사라져”…‘영업 중단’ 치과 피해 잇따라</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/660/0000098448" onclick="nclk(event, 'home.editnfimg', '', '')">토요일 외출길 '빙판길 주의'...중부 곳곳 비 또는 눈</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/660/0000098444" onclick="nclk(event, 'home.editnfimg', '', '')">박지원이 '훈식이형·현지누나' 김남국 옹호한 이유 들어보니..."민주당 특유의 언어 풍토"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/660/0000098447" onclick="nclk(event, 'home.editnfimg', '', '')">김수민 "찬양 고무죄는 UN에서도 문제 삼았던 악법"[박영환의 시사1번지]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/422/0000809085" onclick="nclk(event, 'home.editnfimg', '', '')">'계엄령 놀이' 양양군 공무원 구속…의혹에 "묵묵부답"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/422/0000809043" onclick="nclk(event, 'home.editnfimg', '', '')">'매니저에 갑질 의혹' 방송인 박나래 경찰 수사</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/422/0000809100" onclick="nclk(event, 'home.editnfimg', '', '')">자녀 학폭 문제 처리 불만…둔기 들고 학교 찾아간 학부모 입건</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/007/0000008073" onclick="nclk(event, 'home.editnfimg', '', '')">“올해부터 우리 마을은 남녀차별 없이 임금 지급한다”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/007/0000008072" onclick="nclk(event, 'home.editnfimg', '', '')">‘무지개 노인’도 잘 살 수 있는 나라를 위한 노력</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/007/0000008071" onclick="nclk(event, 'home.editnfimg', '', '')">지하철 장애인 시위 현장의 ‘둘리아’들</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/277/0005689737" onclick="nclk(event, 'home.editnfimg', '', '')">李대통령 "집값으로 욕 그렇게 먹는데 대책이 없다…균형발전 해야"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/277/0005689704" onclick="nclk(event, 'home.editnfimg', '', '')">"원룸에 갇혀있다" 신고 받고 갔더니…이집도 저집도 성매매 현장</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/277/0005689352" onclick="nclk(event, 'home.editnfimg', '', '')">"진짜 기적" 몸도 못폈던 이봉주, 22분30초만에 5㎞ 완주…'불사조' 감동 안겼다</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/293/0000076060" onclick="nclk(event, 'home.editnfimg', '', '')">"효성 차남 조현문, 수임료 감면 위해 대한변협에 징계 요청" [넘버스]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/293/0000076087" onclick="nclk(event, 'home.editnfimg', '', '')">BNK금융 회장 인선, '참호' 논란 잠재울까…승부수는 '정면 돌파'</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/293/0000076084" onclick="nclk(event, 'home.editnfimg', '', '')">[증권사 위탁매매 재편]⑨ "장기 고객 잡아라"...토스증권, 미래 과제는 '신뢰성'</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/586/0000117538" onclick="nclk(event, 'home.editnfimg', '', '')">[속보] 정청래, 1인1표제 무산에 사과 "당분간 재부의 어려워"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/586/0000117537" onclick="nclk(event, 'home.editnfimg', '', '')">이재명 시계 1호 주인공은 정청래…鄭 "李정부 성공 위해 힘쓸 것"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/586/0000117535" onclick="nclk(event, 'home.editnfimg', '', '')">롯데·HD현대케미칼 채권단, 구조조정 자율협의회 첫 소집</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/308/0000037569" onclick="nclk(event, 'home.editnfimg', '', '')">“밖에서는 시민들이, 안에서는 국회 직원들이 목숨을 걸었다” [당신의 6시간 ⑩]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/308/0000037568" onclick="nclk(event, 'home.editnfimg', '', '')">국립중앙박물관에 왜 CT 장비가 설치됐을까</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/308/0000037566" onclick="nclk(event, 'home.editnfimg', '', '')">주인 없는 개는 어디서 살까? [사람IN]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/022/0004087827" onclick="nclk(event, 'home.editnfimg', '', '')">“한국 노렸다” 벌써 4만5000명 감염…확산 속도, 이미 통제 밖?</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/022/0004087970" onclick="nclk(event, 'home.editnfimg', '', '')">가족 간 재산범죄도 처벌 가능… ‘친족상도례 개편’ 형법 법사소위 통과</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/022/0004087833" onclick="nclk(event, 'home.editnfimg', '', '')">이부진 아들, 수능 잘 봤다… 의대 아닌 서울대 OOO 간다</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/044/0000277478" onclick="nclk(event, 'home.editnfimg', '', '')">Korea’s cumulative current-account surplus hits record high in October</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/044/0000277469" onclick="nclk(event, 'home.editnfimg', '', '')">Ministry probes units over unreported Pyongyang leaflet launch accusations</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/044/0000277471" onclick="nclk(event, 'home.editnfimg', '', '')">'Superbugs' surge to record levels in Korea, with infections near 45,000</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/053/0000054062" onclick="nclk(event, 'home.editnfimg', '', '')">"신체 접촉 분명히 했다"...장경태 고소한 비서관 직접 증언</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/053/0000054058" onclick="nclk(event, 'home.editnfimg', '', '')">장래 대통령감 선호도...'군웅할거' 속 조국 1위, 김민석·장동혁·한동훈 순</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/053/0000054063" onclick="nclk(event, 'home.editnfimg', '', '')">도망가자 차로 '쾅', 흉기 휘둘러...층간소음 이유로 이웃 살해한 40대</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/030/0003377788" onclick="nclk(event, 'home.editnfimg', '', '')">“미터기 아예 꺼놓고”… 택시 바가지요금 세계 1위는 튀르키예</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/030/0003377651" onclick="nclk(event, 'home.editnfimg', '', '')">휴대폰 충전하고 자다 감전…온몸이 새까맣게 탄 소년</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/030/0003377701" onclick="nclk(event, 'home.editnfimg', '', '')">日, 매일 잡히는 곰 '사체만 6000마리'… “해체도 어려워, 그냥 먹자”</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/607/0000003061" onclick="nclk(event, 'home.editnfimg', '', '')">[타파의 시선] 이재명 정부, 국정기록관리를 손놓고 있다</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/607/0000003060" onclick="nclk(event, 'home.editnfimg', '', '')">'눈 떠보니 내가 특활비 결재하는 검사장?' 인터렉티브 페이지 공개</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/607/0000003059" onclick="nclk(event, 'home.editnfimg', '', '')">검찰의 '특수활동비 현금 저수지'… 물증 나왔다</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/449/0000328659" onclick="nclk(event, 'home.editnfimg', '', '')">조희대, 표정 돌변하더니 “사법제도, 그릇되게 개편되면…” [현장영상]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/449/0000328645" onclick="nclk(event, 'home.editnfimg', '', '')">‘갑질 의혹’ 박나래 고발당해…의료법 위반·특수상해 등 혐의</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/449/0000328654" onclick="nclk(event, 'home.editnfimg', '', '')">배우 조진웅, 소년범 출신 의혹에 ‘시그널2’ 비상…소속사 “확인 중” [자막뉴스]</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/037/0000037349" onclick="nclk(event, 'home.editnfimg', '', '')">유출된 쿠팡 개인정보, 범죄자들에게 종합선물세트</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/037/0000037348" onclick="nclk(event, 'home.editnfimg', '', '')">전병우·신상열… 연말 재계 3세 고속 승진 바람</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/037/0000037345" onclick="nclk(event, 'home.editnfimg', '', '')">삼성전자, 두 번 접는 갤럭시Z 트라이폴드 공개</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/092/0002400954" onclick="nclk(event, 'home.editnfimg', '', '')">"방어회 반값"…이마트, 고래잇 주말 행사 시작</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/092/0002401168" onclick="nclk(event, 'home.editnfimg', '', '')">"해킹 휘청 한국...'사이버보안 기본법' 만들어야"</a>
#  </li>,
#  <li class="cnf_news_item">
#  <a class="cnf_news _cds_link _editn_link" href="https://n.news.naver.com/article/092/0002401304" onclick="nclk(event, 'home.editnfimg', '', '')">홍성완 클루커스 대표 "내년 글로벌 도약 원년"…90조 美 MSP 시장 승부</a>
#  </li>]

# %%
len(bs_news.select('.comp_news_none .cnf_news_list .cnf_news_item'))
# CSS 선택자에 해당하는 요소들 개수를 출력
# Out:
# 246
